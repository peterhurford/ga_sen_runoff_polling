# %%
import pandas as pd

from mlgear.utils import display_columns
from surveyweights import normalize_weights

# %%
survey = pd.read_csv('responses_processed_with_default_weights.csv')

# %% [markdown]
# ## Raw Demographics

# %%
demographics = ['loc_county', 'gender', 'race', 'education', 'income', 'age', 'vote2016', 'vote2020']
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    72.455516
# Fulton County, GA            10.320285
# Cobb County, GA               8.327402
# Gwinnett County, GA           6.548043
# DeKalb County, GA             2.348754
# Name: loc_county, dtype: float64
# -
# -
# ## gender ##
# Female               53.950178
# Male                 44.768683
# Other                 1.209964
# Prefer not to say     0.071174
# Name: gender, dtype: float64
# -
# -
# ## race ##
# White, not Hispanic    68.113879
# Black, non-Hispanic    21.637011
# Other                   8.469751
# Hispanic                1.779359
# Name: race, dtype: float64
# -
# -
# ## education ##
# Graduated from college        30.960854
# Some college, no degree       30.249110
# Completed graduate school     17.722420
# Graduated from high school    17.295374
# Less than high school          3.772242
# Name: education, dtype: float64
# -
# -
# ## income ##
# Between $15,000 and $49,999      36.725979
# Between $50,000 and $74,999      19.928826
# Under $15,000                    16.441281
# Between $75,000 and $99,999      11.886121
# Between $100,000 and $150,000     8.683274
# Over $150,000                     6.334520
# Name: income, dtype: float64
# -
# -
# ## age ##
# 65 or older    38.576512
# 55-64          22.989324
# 18-34          19.359431
# 35-54          19.074733
# Name: age, dtype: float64
# -
# -
# ## vote2016 ##
# Hillary Clinton    41.637011
# Donald Trump       40.996441
# Did not vote       12.740214
# Other               4.626335
# Name: vote2016, dtype: float64
# -
# -
# ## vote2020 ##
# Joe Biden       55.587189
# Donald Trump    40.498221
# Other            2.206406
# Did not vote     1.708185
# Name: vote2020, dtype: float64
# -
# -

# %% [markdown]
# ## Demographics after weighting

# %%
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * survey.groupby(var)['weight'].mean() * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    66.836368
# Cobb County, GA               7.209118
# DeKalb County, GA             7.138179
# Fulton County, GA             9.997984
# Gwinnett County, GA           8.818350
# dtype: float64
# -
# -
# ## gender ##
# Female               51.056062
# Male                 48.274189
# Other                 0.598637
# Prefer not to say     0.071112
# dtype: float64
# -
# -
# ## race ##
# Black, non-Hispanic    32.575141
# Hispanic                9.897447
# Other                   5.487773
# White, not Hispanic    52.039639
# dtype: float64
# -
# -
# ## education ##
# Completed graduate school      9.119156
# Graduated from college        18.333012
# Graduated from high school    30.075030
# Less than high school         14.067680
# Some college, no degree       28.405122
# dtype: float64
# -
# -
# ## income ##
# Between $100,000 and $150,000    12.076122
# Between $15,000 and $49,999      35.234993
# Between $50,000 and $74,999      18.003221
# Between $75,000 and $99,999      11.610271
# Over $150,000                     9.325114
# Under $15,000                    13.750279
# dtype: float64
# -
# -
# ## age ##
# 18-34          27.726957
# 35-54          35.966024
# 55-64          16.711068
# 65 or older    19.595952
# dtype: float64
# -
# -
# ## vote2016 ##
# Did not vote       12.718887
# Donald Trump       44.092402
# Hillary Clinton    39.436882
# Other               3.751829
# dtype: float64
# -
# -
# ## vote2020 ##
# Did not vote     1.708185
# Donald Trump    48.457865
# Joe Biden       48.654448
# Other            1.179502
# dtype: float64
# -
# -

# %% [markdown]
# ## Expected Vote Demographics (Demographics after Weighting + Likely Voter Model)

# %%
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * survey.groupby(var)['lv_weight'].mean() * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    68.822592
# Cobb County, GA               6.997357
# DeKalb County, GA             5.760525
# Fulton County, GA             9.646536
# Gwinnett County, GA           8.772989
# dtype: float64
# -
# -
# ## gender ##
# Female               50.364356
# Male                 49.141186
# Other                 0.436245
# Prefer not to say     0.058213
# dtype: float64
# -
# -
# ## race ##
# Black, non-Hispanic    32.583761
# Hispanic                9.259468
# Other                   5.350309
# White, not Hispanic    52.806462
# dtype: float64
# -
# -
# ## education ##
# Completed graduate school      9.112139
# Graduated from college        17.868721
# Graduated from high school    29.946849
# Less than high school         15.095818
# Some college, no degree       27.976473
# dtype: float64
# -
# -
# ## income ##
# Between $100,000 and $150,000    12.362446
# Between $15,000 and $49,999      34.353384
# Between $50,000 and $74,999      17.779579
# Between $75,000 and $99,999      12.025944
# Over $150,000                     9.709819
# Under $15,000                    13.768828
# dtype: float64
# -
# -
# ## age ##
# 18-34          24.972205
# 35-54          36.423197
# 55-64          17.691718
# 65 or older    20.912880
# dtype: float64
# -
# -
# ## vote2016 ##
# Did not vote       10.634300
# Donald Trump       46.508904
# Hillary Clinton    39.118504
# Other               3.738293
# dtype: float64
# -
# -
# ## vote2020 ##
# Did not vote     0.623013
# Donald Trump    51.195163
# Joe Biden       47.045216
# Other            1.136608
# dtype: float64
# -
# -

# %% [markdown]
# ## Demographic by Vote

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('-')
        print('---- vote choice for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print('------ "{}" 2016 vote'.format(option))
        print(survey_['vote2016'].value_counts(normalize=True) * survey_.groupby('vote2016')['lv_weight'].mean() * 100)
        print('------ "{}" 2020 vote'.format(option))
        print(survey_['vote2020'].value_counts(normalize=True) * survey_.groupby('vote2020')['lv_weight'].mean() * 100)
        print('------ "{}" Ossoff-Perdue vote'.format(option))
        print(survey_['vote_ossoff_perdue'].value_counts(normalize=True) * survey_.groupby('vote_ossoff_perdue')['lv_weight'].mean() * 100)
        print('------ "{}" Warnock-Loeffler vote'.format(option))
        print(survey_['vote_warnock_loeffler'].value_counts(normalize=True) * survey_.groupby('vote_warnock_loeffler')['lv_weight'].mean() * 100)
    print('-')
    print('-')
    print('-')
    print('-')
# Out:
# ## loc_county ##
# -
# ---- vote choice for "Another county in Georgia"
# ------ "Another county in Georgia" 2016 vote
# Did not vote        7.750357
# Donald Trump       56.413235
# Hillary Clinton    32.334045
# Other               3.502364
# dtype: float64
# ------ "Another county in Georgia" 2020 vote
# Did not vote     0.717223
# Donald Trump    59.393290
# Joe Biden       38.376633
# Other            1.512854
# dtype: float64
# ------ "Another county in Georgia" Ossoff-Perdue vote
# David Perdue    55.606177
# Jon Ossoff      38.295047
# Undecided        6.098776
# dtype: float64
# ------ "Another county in Georgia" Warnock-Loeffler vote
# Kelly Loeffler     57.114737
# Raphael Warnock    39.066555
# Undecided           3.818709
# dtype: float64
# -
# ---- vote choice for "Cobb County, GA"
# ------ "Cobb County, GA" 2016 vote
# Did not vote       10.401862
# Donald Trump       39.157145
# Hillary Clinton    40.232280
# Other              10.208713
# dtype: float64
# ------ "Cobb County, GA" 2020 vote
# Did not vote     0.824986
# Donald Trump    49.370213
# Joe Biden       49.592836
# Other            0.211965
# dtype: float64
# ------ "Cobb County, GA" Ossoff-Perdue vote
# David Perdue    50.835905
# Jon Ossoff      48.922921
# Undecided        0.241174
# dtype: float64
# ------ "Cobb County, GA" Warnock-Loeffler vote
# Kelly Loeffler     48.882583
# Raphael Warnock    49.679436
# Undecided           1.437981
# dtype: float64
# -
# ---- vote choice for "DeKalb County, GA"
# ------ "DeKalb County, GA" 2016 vote
# Did not vote       14.684552
# Donald Trump        9.732590
# Hillary Clinton    74.640538
# Other               0.942320
# dtype: float64
# ------ "DeKalb County, GA" 2020 vote
# Did not vote     0.942320
# Donald Trump     9.170124
# Joe Biden       89.412972
# Other            0.474585
# dtype: float64
# ------ "DeKalb County, GA" Ossoff-Perdue vote
# David Perdue    11.037615
# Jon Ossoff      87.012608
# Undecided        1.949776
# dtype: float64
# ------ "DeKalb County, GA" Warnock-Loeffler vote
# Kelly Loeffler      9.644708
# Raphael Warnock    88.020065
# Undecided           2.335227
# dtype: float64
# -
# ---- vote choice for "Fulton County, GA"
# ------ "Fulton County, GA" 2016 vote
# Did not vote       29.784065
# Donald Trump       19.984075
# Hillary Clinton    47.270043
# Other               2.961817
# dtype: float64
# ------ "Fulton County, GA" 2020 vote
# Did not vote     0.084638
# Donald Trump    27.579971
# Joe Biden       72.078784
# Other            0.256607
# dtype: float64
# ------ "Fulton County, GA" Ossoff-Perdue vote
# David Perdue    25.985507
# Jon Ossoff      70.679375
# Undecided        3.335118
# dtype: float64
# ------ "Fulton County, GA" Warnock-Loeffler vote
# Kelly Loeffler     26.19218
# Raphael Warnock    71.74069
# Undecided           2.06713
# dtype: float64
# -
# ---- vote choice for "Gwinnett County, GA"
# ------ "Gwinnett County, GA" 2016 vote
# Did not vote        9.727697
# Donald Trump       27.988965
# Hillary Clinton    59.165357
# Other               3.117981
# dtype: float64
# ------ "Gwinnett County, GA" 2020 vote
# Did not vote     0.105170
# Donald Trump    41.898971
# Joe Biden       57.671016
# Other            0.324843
# dtype: float64
# ------ "Gwinnett County, GA" Ossoff-Perdue vote
# David Perdue    40.568872
# Jon Ossoff      56.858311
# Undecided        2.572816
# dtype: float64
# ------ "Gwinnett County, GA" Warnock-Loeffler vote
# Kelly Loeffler     40.488688
# Raphael Warnock    56.272664
# Undecided           3.238648
# dtype: float64
# -
# -
# -
# -
# ## gender ##
# -
# ---- vote choice for "Female"
# ------ "Female" 2016 vote
# Did not vote       12.288203
# Donald Trump       42.998734
# Hillary Clinton    40.668214
# Other               4.044849
# dtype: float64
# ------ "Female" 2020 vote
# Did not vote     0.585686
# Donald Trump    47.045309
# Joe Biden       50.757276
# Other            1.611730
# dtype: float64
# ------ "Female" Ossoff-Perdue vote
# David Perdue    45.002394
# Jon Ossoff      50.116819
# Undecided        4.880788
# dtype: float64
# ------ "Female" Warnock-Loeffler vote
# Kelly Loeffler     44.433084
# Raphael Warnock    50.762813
# Undecided           4.804103
# dtype: float64
# -
# ---- vote choice for "Male"
# ------ "Male" 2016 vote
# Did not vote        8.610319
# Donald Trump       50.416970
# Hillary Clinton    37.597837
# Other               3.374874
# dtype: float64
# ------ "Male" 2020 vote
# Did not vote     0.275732
# Donald Trump    55.807914
# Joe Biden       43.257183
# Other            0.659172
# dtype: float64
# ------ "Male" Ossoff-Perdue vote
# David Perdue    52.083843
# Jon Ossoff      43.002066
# Undecided        4.914090
# dtype: float64
# ------ "Male" Warnock-Loeffler vote
# Kelly Loeffler     54.375624
# Raphael Warnock    43.739383
# Undecided           1.884993
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       49.103762
# Donald Trump       17.735745
# Hillary Clinton    23.377490
# Other               9.783003
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote    44.135345
# Donald Trump    17.518951
# Joe Biden       38.128910
# Other            0.216794
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    61.577090
# Jon Ossoff      38.206115
# Undecided        0.216794
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     60.369823
# Raphael Warnock    39.413383
# Undecided           0.216794
# dtype: float64
# -
# ---- vote choice for "Prefer not to say"
# ------ "Prefer not to say" 2016 vote
# Hillary Clinton    100.0
# dtype: float64
# ------ "Prefer not to say" 2020 vote
# Joe Biden    100.0
# dtype: float64
# ------ "Prefer not to say" Ossoff-Perdue vote
# Jon Ossoff    100.0
# dtype: float64
# ------ "Prefer not to say" Warnock-Loeffler vote
# Raphael Warnock    100.0
# dtype: float64
# -
# -
# -
# -
# ## race ##
# -
# ---- vote choice for "White, not Hispanic"
# ------ "White, not Hispanic" 2016 vote
# Did not vote        7.808255
# Donald Trump       69.564047
# Hillary Clinton    19.373770
# Other               3.253928
# dtype: float64
# ------ "White, not Hispanic" 2020 vote
# Did not vote     0.429446
# Donald Trump    74.472513
# Joe Biden       24.803522
# Other            0.294519
# dtype: float64
# ------ "White, not Hispanic" Ossoff-Perdue vote
# David Perdue    72.487102
# Jon Ossoff      24.389785
# Undecided        3.123112
# dtype: float64
# ------ "White, not Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     72.792661
# Raphael Warnock    24.454244
# Undecided           2.753095
# dtype: float64
# -
# ---- vote choice for "Black, non-Hispanic"
# ------ "Black, non-Hispanic" 2016 vote
# Did not vote       12.336752
# Donald Trump        9.657974
# Hillary Clinton    73.788995
# Other               4.216279
# dtype: float64
# ------ "Black, non-Hispanic" 2020 vote
# Did not vote     0.368024
# Donald Trump    16.713150
# Joe Biden       81.809960
# Other            1.108866
# dtype: float64
# ------ "Black, non-Hispanic" Ossoff-Perdue vote
# David Perdue    11.401888
# Jon Ossoff      81.788403
# Undecided        6.809708
# dtype: float64
# ------ "Black, non-Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     13.663236
# Raphael Warnock    83.750415
# Undecided           2.586349
# dtype: float64
# -
# ---- vote choice for "Hispanic"
# ------ "Hispanic" 2016 vote
# Did not vote       15.833438
# Donald Trump       52.549024
# Hillary Clinton    31.617538
# dtype: float64
# ------ "Hispanic" 2020 vote
# Did not vote     2.054648
# Donald Trump    50.880782
# Joe Biden       45.269026
# Other            1.795544
# dtype: float64
# ------ "Hispanic" Ossoff-Perdue vote
# David Perdue    52.93543
# Jon Ossoff      42.06305
# Undecided        5.00152
# dtype: float64
# ------ "Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     54.040885
# Raphael Warnock    42.063050
# Undecided           3.896065
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       19.160881
# Donald Trump       32.930817
# Hillary Clinton    35.830743
# Other              12.077559
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote     1.608728
# Donald Trump    31.994434
# Joe Biden       57.920414
# Other            8.476423
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    30.537185
# Jon Ossoff      59.317850
# Undecided       10.144966
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     27.428318
# Raphael Warnock    59.684344
# Undecided          12.887338
# dtype: float64
# -
# -
# -
# -
# ## education ##
# -
# ---- vote choice for "Completed graduate school"
# ------ "Completed graduate school" 2016 vote
# Did not vote        2.645118
# Donald Trump       32.517483
# Hillary Clinton    58.511320
# Other               6.326079
# dtype: float64
# ------ "Completed graduate school" 2020 vote
# Did not vote     0.089602
# Donald Trump    38.829261
# Joe Biden       60.743005
# Other            0.338133
# dtype: float64
# ------ "Completed graduate school" Ossoff-Perdue vote
# David Perdue    40.778444
# Jon Ossoff      59.020536
# Undecided        0.201020
# dtype: float64
# ------ "Completed graduate school" Warnock-Loeffler vote
# Kelly Loeffler     39.172856
# Raphael Warnock    59.115518
# Undecided           1.711626
# dtype: float64
# -
# ---- vote choice for "Graduated from high school"
# ------ "Graduated from high school" 2016 vote
# Did not vote        6.343067
# Donald Trump       58.849588
# Hillary Clinton    31.375310
# Other               3.432035
# dtype: float64
# ------ "Graduated from high school" 2020 vote
# Did not vote     1.183121
# Donald Trump    58.701551
# Joe Biden       39.878705
# Other            0.236623
# dtype: float64
# ------ "Graduated from high school" Ossoff-Perdue vote
# David Perdue    55.570088
# Jon Ossoff      39.293954
# Undecided        5.135958
# dtype: float64
# <ipython-input-149-4d9642e6df09>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# ------ "Graduated from high school" Warnock-Loeffler vote
# Kelly Loeffler     54.175218
# Raphael Warnock    43.421703
# Undecided           2.403078
# dtype: float64
# -
# ---- vote choice for "Graduated from college"
# ------ "Graduated from college" 2016 vote
# Did not vote       11.790614
# Donald Trump       31.560659
# Hillary Clinton    51.692331
# Other               4.956396
# dtype: float64
# ------ "Graduated from college" 2020 vote
# Did not vote     0.718612
# Donald Trump    45.546812
# Joe Biden       53.128643
# Other            0.605932
# dtype: float64
# ------ "Graduated from college" Ossoff-Perdue vote
# David Perdue    43.790355
# Jon Ossoff      53.791472
# Undecided        2.418173
# dtype: float64
# ------ "Graduated from college" Warnock-Loeffler vote
# Kelly Loeffler     44.502756
# Raphael Warnock    53.749824
# Undecided           1.747420
# dtype: float64
# -
# ---- vote choice for "Some college, no degree"
# ------ "Some college, no degree" 2016 vote
# Did not vote       15.237980
# Donald Trump       46.695165
# Hillary Clinton    36.146488
# Other               1.920367
# dtype: float64
# ------ "Some college, no degree" 2020 vote
# Did not vote     0.472303
# Donald Trump    51.421462
# Joe Biden       47.191600
# Other            0.914635
# dtype: float64
# ------ "Some college, no degree" Ossoff-Perdue vote
# David Perdue    47.859337
# Jon Ossoff      48.270581
# Undecided        3.870083
# dtype: float64
# ------ "Some college, no degree" Warnock-Loeffler vote
# Kelly Loeffler     47.502922
# Raphael Warnock    48.459281
# Undecided           4.037797
# dtype: float64
# -
# ---- vote choice for "Less than high school"
# ------ "Less than high school" 2016 vote
# Did not vote       14.069080
# Donald Trump       47.822000
# Hillary Clinton    33.397879
# Other               4.711041
# dtype: float64
# ------ "Less than high school" 2020 vote
# Donald Trump    50.034900
# Joe Biden       45.521611
# Other            4.443489
# dtype: float64
# ------ "Less than high school" Ossoff-Perdue vote
# David Perdue    46.085620
# Jon Ossoff      41.972123
# Undecided       11.942257
# dtype: float64
# ------ "Less than high school" Warnock-Loeffler vote
# Kelly Loeffler     55.165291
# Raphael Warnock    38.016117
# Undecided           6.818592
# dtype: float64
# -
# -
# -
# -
# ## income ##
# -
# ---- vote choice for "Between $100,000 and $150,000"
# ------ "Between $100,000 and $150,000" 2016 vote
# Did not vote        7.827711
# Donald Trump       40.986308
# Hillary Clinton    48.225368
# Other               2.960612
# dtype: float64
# ------ "Between $100,000 and $150,000" 2020 vote
# Donald Trump    51.763050
# Joe Biden       47.711013
# Other            0.525937
# dtype: float64
# ------ "Between $100,000 and $150,000" Ossoff-Perdue vote
# David Perdue    51.210807
# Jon Ossoff      48.551967
# Undecided        0.237225
# dtype: float64
# ------ "Between $100,000 and $150,000" Warnock-Loeffler vote
# Kelly Loeffler     52.495232
# Raphael Warnock    47.045632
# Undecided           0.459136
# dtype: float64
# -
# ---- vote choice for "Between $50,000 and $74,999"
# ------ "Between $50,000 and $74,999" 2016 vote
# Did not vote        7.488068
# Donald Trump       50.644070
# Hillary Clinton    38.250773
# Other               3.617090
# dtype: float64
# ------ "Between $50,000 and $74,999" 2020 vote
# Did not vote     0.329042
# Donald Trump    49.802740
# Joe Biden       46.225313
# Other            3.642905
# dtype: float64
# ------ "Between $50,000 and $74,999" Ossoff-Perdue vote
# David Perdue    50.842706
# Jon Ossoff      45.435125
# Undecided        3.722168
# dtype: float64
# ------ "Between $50,000 and $74,999" Warnock-Loeffler vote
# Kelly Loeffler     50.566920
# Raphael Warnock    45.101709
# Undecided           4.331371
# dtype: float64
# -
# ---- vote choice for "Between $15,000 and $49,999"
# ------ "Between $15,000 and $49,999" 2016 vote
# Did not vote       13.490352
# Donald Trump       47.590939
# Hillary Clinton    35.930556
# Other               2.988153
# dtype: float64
# ------ "Between $15,000 and $49,999" 2020 vote
# Did not vote     1.210018
# Donald Trump    50.808677
# Joe Biden       47.845667
# Other            0.135639
# dtype: float64
# ------ "Between $15,000 and $49,999" Ossoff-Perdue vote
# David Perdue    46.399559
# Jon Ossoff      46.564132
# Undecided        7.036309
# dtype: float64
# ------ "Between $15,000 and $49,999" Warnock-Loeffler vote
# Kelly Loeffler     45.546177
# Raphael Warnock    49.697465
# Undecided           4.756358
# dtype: float64
# -
# ---- vote choice for "Under $15,000"
# ------ "Under $15,000" 2016 vote
# Did not vote       16.545603
# Donald Trump       36.848339
# Hillary Clinton    41.400423
# Other               5.205635
# dtype: float64
# ------ "Under $15,000" 2020 vote
# Did not vote     0.660769
# Donald Trump    36.752175
# Joe Biden       60.050361
# Other            2.536696
# dtype: float64
# ------ "Under $15,000" Ossoff-Perdue vote
# David Perdue    34.541796
# Jon Ossoff      54.290522
# Undecided       11.167682
# dtype: float64
# ------ "Under $15,000" Warnock-Loeffler vote
# Kelly Loeffler     42.125875
# Raphael Warnock    53.078049
# Undecided           4.796077
# dtype: float64
# -
# ---- vote choice for "Between $75,000 and $99,999"
# ------ "Between $75,000 and $99,999" 2016 vote
# Did not vote        2.136437
# Donald Trump       54.093474
# Hillary Clinton    41.124038
# Other               2.646051
# dtype: float64
# ------ "Between $75,000 and $99,999" 2020 vote
# Did not vote     0.390205
# Donald Trump    64.657180
# Joe Biden       34.719565
# Other            0.233050
# dtype: float64
# ------ "Between $75,000 and $99,999" Ossoff-Perdue vote
# David Perdue    55.431769
# Jon Ossoff      42.902935
# Undecided        1.665297
# dtype: float64
# ------ "Between $75,000 and $99,999" Warnock-Loeffler vote
# Kelly Loeffler     55.858142
# Raphael Warnock    42.476561
# Undecided           1.665297
# dtype: float64
# -
# ---- vote choice for "Over $150,000"
# ------ "Over $150,000" 2016 vote
# Did not vote       12.006416
# Donald Trump       46.445333
# Hillary Clinton    34.671846
# Other               6.876405
# dtype: float64
# ------ "Over $150,000" 2020 vote
# Did not vote     0.112488
# Donald Trump    58.196621
# Joe Biden       41.690891
# dtype: float64
# ------ "Over $150,000" Ossoff-Perdue vote
# David Perdue    59.690821
# Jon Ossoff      40.023738
# Undecided        0.285440
# dtype: float64
# ------ "Over $150,000" Warnock-Loeffler vote
# Kelly Loeffler     58.888654
# Raphael Warnock    40.850290
# Undecided           0.261055
# dtype: float64
# -
# -
# -
# -
# ## age ##
# -
# ---- vote choice for "18-34"
# ------ "18-34" 2016 vote
# Did not vote       27.098575
# Donald Trump       31.266623
# Hillary Clinton    38.192754
# Other               3.442048
# dtype: float64
# ------ "18-34" 2020 vote
# Did not vote     1.003144
# Donald Trump    34.758682
# Joe Biden       62.702373
# Other            1.535801
# dtype: float64
# ------ "18-34" Ossoff-Perdue vote
# David Perdue    31.922706
# Jon Ossoff      60.479966
# Undecided        7.597328
# dtype: float64
# ------ "18-34" Warnock-Loeffler vote
# Kelly Loeffler     35.848123
# Raphael Warnock    61.105499
# Undecided           3.046378
# dtype: float64
# -
# ---- vote choice for "35-54"
# ------ "35-54" 2016 vote
# Did not vote        6.130326
# Donald Trump       51.904655
# Hillary Clinton    37.222689
# Other               4.742330
# dtype: float64
# ------ "35-54" 2020 vote
# Did not vote     0.789575
# Donald Trump    58.957879
# Joe Biden       38.302349
# Other            1.950197
# dtype: float64
# ------ "35-54" Ossoff-Perdue vote
# David Perdue    55.749861
# Jon Ossoff      40.349054
# Undecided        3.901086
# dtype: float64
# ------ "35-54" Warnock-Loeffler vote
# Kelly Loeffler     54.748680
# Raphael Warnock    41.373609
# Undecided           3.877711
# dtype: float64
# -
# ---- vote choice for "55-64"
# ------ "55-64" 2016 vote
# Did not vote        4.892754
# Donald Trump       46.861855
# Hillary Clinton    44.072352
# Other               4.173038
# dtype: float64
# ------ "55-64" 2020 vote
# Did not vote     0.160899
# Donald Trump    52.325377
# Joe Biden       47.347043
# Other            0.166680
# dtype: float64
# ------ "55-64" Ossoff-Perdue vote
# David Perdue    49.856407
# Jon Ossoff      44.252407
# Undecided        5.891186
# dtype: float64
# ------ "55-64" Warnock-Loeffler vote
# Kelly Loeffler     48.863873
# Raphael Warnock    46.760932
# Undecided           4.375195
# dtype: float64
# -
# ---- vote choice for "65 or older"
# ------ "65 or older" 2016 vote
# Did not vote        3.675796
# Donald Trump       55.013641
# Hillary Clinton    39.334999
# Other               1.975563
# dtype: float64
# ------ "65 or older" 2020 vote
# Did not vote     0.269934
# Donald Trump    56.345902
# Joe Biden       43.320700
# Other            0.063464
# dtype: float64
# ------ "65 or older" Ossoff-Perdue vote
# David Perdue    54.656607
# Jon Ossoff      42.887524
# Undecided        2.455869
# dtype: float64
# ------ "65 or older" Warnock-Loeffler vote
# Kelly Loeffler     56.541606
# Raphael Warnock    41.547477
# Undecided           1.910917
# dtype: float64
# -
# -
# -
# -
# ## vote2016 ##
# -
# ---- vote choice for "Hillary Clinton"
# ------ "Hillary Clinton" 2016 vote
# Hillary Clinton    100.0
# dtype: float64
# ------ "Hillary Clinton" 2020 vote
# Donald Trump     6.803522
# Joe Biden       93.118493
# Other            0.077985
# dtype: float64
# ------ "Hillary Clinton" Ossoff-Perdue vote
# David Perdue     5.941517
# Jon Ossoff      91.214503
# Undecided        2.843980
# dtype: float64
# ------ "Hillary Clinton" Warnock-Loeffler vote
# Kelly Loeffler      7.791888
# Raphael Warnock    90.880182
# Undecided           1.327931
# dtype: float64
# -
# ---- vote choice for "Did not vote"
# ------ "Did not vote" 2016 vote
# Did not vote    100.0
# dtype: float64
# ------ "Did not vote" 2020 vote
# Did not vote     4.476908
# Donald Trump    18.813436
# Joe Biden       73.654390
# Other            3.055266
# dtype: float64
# ------ "Did not vote" Ossoff-Perdue vote
# David Perdue    23.874199
# Jon Ossoff      69.508418
# Undecided        6.617383
# dtype: float64
# ------ "Did not vote" Warnock-Loeffler vote
# Kelly Loeffler     21.172801
# Raphael Warnock    71.483304
# Undecided           7.343895
# dtype: float64
# -
# ---- vote choice for "Donald Trump"
# ------ "Donald Trump" 2016 vote
# Donald Trump    100.0
# dtype: float64
# ------ "Donald Trump" 2020 vote
# Did not vote     0.106697
# Donald Trump    96.558530
# Joe Biden        3.289246
# Other            0.045527
# dtype: float64
# ------ "Donald Trump" Ossoff-Perdue vote
# David Perdue    90.957085
# Jon Ossoff       5.042123
# Undecided        4.000792
# dtype: float64
# ------ "Donald Trump" Warnock-Loeffler vote
# Kelly Loeffler     91.951192
# Raphael Warnock     6.255275
# Undecided           1.793533
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Other    100.0
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote     2.602827
# Donald Trump    43.461970
# Joe Biden       33.604492
# Other           20.330712
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    36.438589
# Jon Ossoff      31.541284
# Undecided       32.020127
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     34.707898
# Raphael Warnock    32.865060
# Undecided          32.427042
# dtype: float64
# -
# -
# -
# -
# ## vote2020 ##
# -
# ---- vote choice for "Joe Biden"
# ------ "Joe Biden" 2016 vote
# Did not vote       16.649150
# Donald Trump        3.251749
# Hillary Clinton    77.428831
# Other               2.670270
# dtype: float64
# ------ "Joe Biden" 2020 vote
# Joe Biden    100.0
# dtype: float64
# ------ "Joe Biden" Ossoff-Perdue vote
# David Perdue     2.036298
# Jon Ossoff      94.755032
# Undecided        3.208671
# dtype: float64
# ------ "Joe Biden" Warnock-Loeffler vote
# Kelly Loeffler      3.206467
# Raphael Warnock    94.897625
# Undecided           1.895908
# dtype: float64
# -
# ---- vote choice for "Donald Trump"
# ------ "Donald Trump" 2016 vote
# Did not vote        3.907942
# Donald Trump       87.719838
# Hillary Clinton     5.198608
# Other               3.173612
# dtype: float64
# ------ "Donald Trump" 2020 vote
# Donald Trump    100.0
# dtype: float64
# ------ "Donald Trump" Ossoff-Perdue vote
# David Perdue    92.053853
# Jon Ossoff       3.483719
# Undecided        4.462428
# dtype: float64
# ------ "Donald Trump" Warnock-Loeffler vote
# Kelly Loeffler     92.657130
# Raphael Warnock     4.647755
# Undecided           2.695115
# dtype: float64
# -
# ---- vote choice for "Did not vote"
# ------ "Did not vote" 2016 vote
# Did not vote    76.417022
# Donald Trump     7.965114
# Other           15.617864
# dtype: float64
# ------ "Did not vote" 2020 vote
# Did not vote    100.0
# dtype: float64
# ------ "Did not vote" Ossoff-Perdue vote
# David Perdue    57.911595
# Jon Ossoff      16.727425
# Undecided       25.360980
# dtype: float64
# ------ "Did not vote" Warnock-Loeffler vote
# Kelly Loeffler     58.278948
# Raphael Warnock    21.531574
# Undecided          20.189479
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       28.585592
# Donald Trump        1.862907
# Hillary Clinton     2.683985
# Other              66.867516
# dtype: float64
# ------ "Other" 2020 vote
# Other    100.0
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue     7.259615
# Jon Ossoff      11.631511
# Undecided       81.108875
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler      4.845975
# Raphael Warnock    11.631511
# Undecided          83.522514
# dtype: float64
# -
# -
# -
# -

# %% [markdown]
# ## Vote by Demographic

# %%
for vote in ['vote_ossoff_perdue', 'vote_warnock_loeffler']:
    for choice in survey[vote].unique():
        for var in demographics:
            print('{} = {}, broken down by {}'.format(vote, choice, var))
            survey_ = survey[survey[vote] == choice]
            survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
            print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['lv_weight'].mean() * 100)
            print('-')
        print('-')
        print('-')
# Out:
# vote_ossoff_perdue = Jon Ossoff, broken down by loc_county
# Another county in Georgia    56.560060
# Cobb County, GA               7.346536
# DeKalb County, GA            10.756736
# Fulton County, GA            14.631887
# Gwinnett County, GA          10.704781
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by gender
# Female               54.168026
# Male                 45.349363
# Other                 0.357684
# Prefer not to say     0.124927
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by race
# Black, non-Hispanic    57.191195
# Hispanic                8.358398
# Other                   6.810838
# White, not Hispanic    27.639570
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by education
# Completed graduate school     11.541432
# Graduated from college        20.627336
# Graduated from high school    25.253007
# Less than high school         13.597336
# Some college, no degree       28.980889
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by income
# Between $100,000 and $150,000    12.880937
# Between $15,000 and $49,999      34.328692
# Between $50,000 and $74,999      17.336022
# Between $75,000 and $99,999      11.072417
# Over $150,000                     8.339980
# Under $15,000                    16.041952
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by age
# 18-34          32.411912
# 35-54          31.538980
# 55-64          16.801310
# 65 or older    19.247798
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by vote2016
# Did not vote       15.862898
# Donald Trump        5.032523
# Hillary Clinton    76.574181
# Other               2.530399
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by vote2020
# Did not vote     0.223647
# Donald Trump     3.827439
# Joe Biden       95.665199
# Other            0.283716
# dtype: float64
# -
# -
# -
# vote_ossoff_perdue = David Perdue, broken down by loc_county
# Another county in Georgia    78.860222
# Cobb County, GA               7.330077
# DeKalb County, GA             1.310211
# Fulton County, GA             5.165430
# Gwinnett County, GA           7.334060
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by gender
# Female    46.704941
# Male      52.741513
# Other      0.553546
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by race
# Black, non-Hispanic     7.655647
# Hispanic               10.100350
# Other                   3.366757
# White, not Hispanic    78.877245
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by education
# Completed graduate school      7.656934
# Graduated from college        16.124114
# Graduated from high school    34.292263
# Less than high school         14.335935
# Some college, no degree       27.590753
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by income
# Between $100,000 and $150,000    13.045777
# Between $15,000 and $49,999      32.846364
# Between $50,000 and $74,999      18.627478
# Between $75,000 and $99,999      13.736682
# Over $150,000                    11.943253
# Under $15,000                     9.800445
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by age
# 18-34          16.427085
# 35-54          41.843286
# 55-64          18.175858
# 65 or older    23.553770
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by vote2016
# Did not vote        5.231686
# Donald Trump       87.171911
# Hillary Clinton     4.789426
# Other               2.806977
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by vote2020
# Did not vote     0.743475
# Donald Trump    97.112433
# Joe Biden        1.974061
# Other            0.170031
# dtype: float64
# -
# -
# -
# vote_ossoff_perdue = Undecided, broken down by loc_county
# Another county in Georgia    86.117476
# Cobb County, GA               0.346244
# DeKalb County, GA             2.304435
# Fulton County, GA             6.600855
# Gwinnett County, GA           4.630991
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by gender
# Female    50.434854
# Male      49.545742
# Other      0.019404
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by race
# Black, non-Hispanic    45.524721
# Hispanic                9.501793
# Other                  11.136457
# White, not Hispanic    33.837029
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by education
# Completed graduate school      0.375818
# Graduated from college         8.865401
# Graduated from high school    31.556597
# Less than high school         36.987979
# Some college, no degree       22.214204
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by income
# Between $100,000 and $150,000     0.601704
# Between $15,000 and $49,999      49.594328
# Between $50,000 and $74,999      13.577977
# Between $75,000 and $99,999       4.108927
# Over $150,000                     0.568649
# Under $15,000                    31.548415
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by age
# 18-34          38.925601
# 35-54          29.152857
# 55-64          21.384068
# 65 or older    10.537474
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by vote2016
# Did not vote       14.438189
# Donald Trump       38.176810
# Hillary Clinton    22.825816
# Other              24.559185
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by vote2020
# Did not vote     3.241757
# Donald Trump    46.872455
# Joe Biden       30.971209
# Other           18.914579
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by loc_county
# Another county in Georgia    56.854077
# Cobb County, GA               7.350826
# DeKalb County, GA            10.721838
# Fulton County, GA            14.633979
# Gwinnett County, GA          10.439280
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by gender
# Female               54.062290
# Male                 45.451034
# Other                 0.363580
# Prefer not to say     0.123097
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by race
# Black, non-Hispanic    57.705027
# Hispanic                8.235923
# Other                   6.752503
# White, not Hispanic    27.306547
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by education
# Completed graduate school     11.390618
# Graduated from college        20.309349
# Graduated from high school    27.496883
# Less than high school         12.135282
# Some college, no degree       28.667868
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by income
# Between $100,000 and $150,000    12.298416
# Between $15,000 and $49,999      36.101831
# Between $50,000 and $74,999      16.956646
# Between $75,000 and $99,999      10.801747
# Over $150,000                     8.387485
# Under $15,000                    15.453875
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by age
# 18-34          32.267302
# 35-54          31.865955
# 55-64          17.493578
# 65 or older    18.373165
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by vote2016
# Did not vote       16.074556
# Donald Trump        6.151882
# Hillary Clinton    75.175598
# Other               2.597965
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by vote2020
# Did not vote     0.283660
# Donald Trump     5.031501
# Joe Biden       94.405280
# Other            0.279558
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Undecided, broken down by loc_county
# Another county in Georgia    78.526569
# Cobb County, GA               3.006466
# DeKalb County, GA             4.019391
# Fulton County, GA             5.958106
# Gwinnett County, GA           8.489468
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by gender
# Female    72.294403
# Male      27.677339
# Other      0.028258
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by race
# Black, non-Hispanic    25.180094
# Hispanic               10.779070
# Other                  20.602085
# White, not Hispanic    43.438750
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by education
# Completed graduate school      4.660132
# Graduated from college         9.329534
# Graduated from high school    21.502457
# Less than high school         30.755334
# Some college, no degree       33.752542
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by income
# Between $100,000 and $150,000     1.695958
# Between $15,000 and $49,999      48.821722
# Between $50,000 and $74,999      23.009964
# Between $75,000 and $99,999       5.983839
# Over $150,000                     0.757378
# Under $15,000                    19.731139
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by age
# 18-34          22.730543
# 35-54          42.200982
# 55-64          23.127915
# 65 or older    11.940560
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by vote2016
# Did not vote       23.334819
# Donald Trump       24.923822
# Hillary Clinton    15.521251
# Other              36.220108
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by vote2020
# Did not vote     3.758297
# Donald Trump    41.226388
# Joe Biden       26.650278
# Other           28.365037
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by loc_county
# Another county in Georgia    79.630780
# Cobb County, GA               6.929309
# DeKalb County, GA             1.125519
# Fulton County, GA             5.118525
# Gwinnett County, GA           7.195866
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by gender
# Female    45.334780
# Male      54.131699
# Other      0.533522
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by race
# Black, non-Hispanic     9.018962
# Hispanic               10.137019
# Other                   2.972897
# White, not Hispanic    77.871122
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by education
# Completed graduate school      7.231149
# Graduated from college        16.109503
# Graduated from high school    32.866509
# Less than high school         16.870359
# Some college, no degree       26.922479
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by income
# Between $100,000 and $150,000    13.146981
# Between $15,000 and $49,999      31.697370
# Between $50,000 and $74,999      18.213346
# Between $75,000 and $99,999      13.608412
# Over $150,000                    11.583626
# Under $15,000                    11.750265
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by age
# 18-34          18.135314
# 35-54          40.397407
# 55-64          17.512965
# 65 or older    23.954314
# dtype: float64
# <ipython-input-150-3b9602026824>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by vote2016
# Did not vote        4.561303
# Donald Trump       86.635370
# Hillary Clinton     6.174854
# Other               2.628472
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by vote2020
# Did not vote     0.735547
# Donald Trump    96.096937
# Joe Biden        3.055934
# Other            0.111582
# dtype: float64
# -
# -
# -

# %% [markdown]
# ## Demographic by Likely Voter

# %%
demographics += ['vote_warnock_loeffler', 'vote_ossoff_perdue']
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- likely voter breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['lv_likely'].value_counts(normalize=True) * survey_.groupby('lv_likely')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- likely voter breakdown for "Another county in Georgia"
# Already voted      59.150365
# Likely              1.621199
# Somewhat likely     1.168048
# Very likely        40.716662
# dtype: float64
# -
# ---- likely voter breakdown for "Cobb County, GA"
# Already voted      56.969284
# Likely              0.534410
# Somewhat likely     1.241100
# Very likely        37.094769
# dtype: float64
# -
# ---- likely voter breakdown for "DeKalb County, GA"
# Likely              0.686027
# Somewhat likely     2.546646
# Very likely        90.341492
# dtype: float64
# -
# ---- likely voter breakdown for "Fulton County, GA"
# Already voted      41.808485
# Likely              0.563972
# Somewhat likely     0.577118
# Very likely        58.275725
# dtype: float64
# -
# ---- likely voter breakdown for "Gwinnett County, GA"
# Already voted      42.523079
# Likely              1.955894
# Somewhat likely     0.664384
# Very likely        54.491970
# dtype: float64
# -
# ## gender ##
# ---- likely voter breakdown for "Female"
# Already voted      47.390133
# Likely              0.753368
# Somewhat likely     0.736492
# Very likely        48.047124
# dtype: float64
# -
# ---- likely voter breakdown for "Male"
# Already voted      56.956310
# Likely              1.927592
# Somewhat likely     1.539013
# Very likely        41.771704
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted    81.683842
# Likely            1.541738
# Very likely      16.774419
# dtype: float64
# -
# ---- likely voter breakdown for "Prefer not to say"
# Likely    100.0
# dtype: float64
# -
# ## race ##
# ---- likely voter breakdown for "White, not Hispanic"
# Already voted      49.933263
# Likely              1.693354
# Somewhat likely     1.602038
# Very likely        48.441707
# dtype: float64
# -
# ---- likely voter breakdown for "Black, non-Hispanic"
# Already voted      56.393946
# Likely              0.481447
# Somewhat likely     0.320445
# Very likely        40.489899
# dtype: float64
# -
# ---- likely voter breakdown for "Hispanic"
# Already voted    58.950712
# Likely            2.700028
# Very likely      42.387410
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      49.027970
# Likely              2.521313
# Somewhat likely     3.318810
# Very likely        47.701422
# dtype: float64
# -
# ## education ##
# ---- likely voter breakdown for "Completed graduate school"
# Already voted      67.567838
# Likely              2.118136
# Somewhat likely     1.458746
# Very likely        27.536367
# dtype: float64
# -
# ---- likely voter breakdown for "Graduated from high school"
# Already voted      51.359372
# Likely              1.027229
# Somewhat likely     0.711732
# Very likely        41.823011
# dtype: float64
# -
# ---- likely voter breakdown for "Graduated from college"
# Already voted      42.312627
# Likely              1.601932
# Somewhat likely     0.564821
# Very likely        51.328309
# dtype: float64
# -
# ---- likely voter breakdown for "Some college, no degree"
# Already voted      38.614867
# Likely              2.163024
# Somewhat likely     1.391742
# Very likely        56.649963
# dtype: float64
# -
# ---- likely voter breakdown for "Less than high school"
# Already voted      72.639612
# Somewhat likely     1.731917
# Very likely        25.628472
# dtype: float64
# -
# ## income ##
# ---- likely voter breakdown for "Between $100,000 and $150,000"
# Already voted      53.071497
# Likely              1.438640
# Somewhat likely     0.127741
# Very likely        49.913458
# dtype: float64
# -
# ---- likely voter breakdown for "Between $50,000 and $74,999"
# Already voted      49.616937
# Likely              1.940916
# Somewhat likely     1.117380
# Very likely        43.414651
# dtype: float64
# -
# ---- likely voter breakdown for "Between $15,000 and $49,999"
# Already voted      51.252674
# Likely              1.212849
# Somewhat likely     0.573171
# Very likely        43.447853
# dtype: float64
# -
# ---- likely voter breakdown for "Under $15,000"
# Already voted      64.660852
# Likely              1.514373
# Somewhat likely     3.437248
# Very likely        34.576299
# dtype: float64
# -
# ---- likely voter breakdown for "Between $75,000 and $99,999"
# Already voted      43.762422
# Likely              1.937163
# Somewhat likely     1.965146
# Very likely        53.403695
# dtype: float64
# -
# ---- likely voter breakdown for "Over $150,000"
# Already voted    52.065344
# Likely            0.229283
# Very likely      48.137344
# dtype: float64
# -
# ## age ##
# ---- likely voter breakdown for "18-34"
# Already voted      44.383725
# Likely              4.297162
# Somewhat likely     0.983069
# Very likely        58.414309
# dtype: float64
# -
# ---- likely voter breakdown for "35-54"
# Already voted      41.936314
# Likely              1.423552
# Somewhat likely     0.863076
# Very likely        62.723647
# dtype: float64
# -
# ---- likely voter breakdown for "55-64"
# Already voted      69.257238
# Likely              0.125130
# Somewhat likely     1.258855
# Very likely        31.912112
# dtype: float64
# -
# ---- likely voter breakdown for "65 or older"
# Already voted      74.604632
# Somewhat likely     1.813375
# Very likely        24.605322
# dtype: float64
# -
# ## vote2016 ##
# ---- likely voter breakdown for "Hillary Clinton"
# Already voted      60.649903
# Likely              1.399381
# Somewhat likely     0.528823
# Very likely        34.736651
# dtype: float64
# -
# ---- likely voter breakdown for "Did not vote"
# Already voted      27.374312
# Likely              6.341247
# Somewhat likely     2.370631
# Very likely        59.637746
# dtype: float64
# -
# ---- likely voter breakdown for "Donald Trump"
# Already voted      48.432991
# Likely              0.235828
# Somewhat likely     1.027049
# Very likely        50.957168
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      77.345116
# Likely              2.574614
# Somewhat likely     4.966643
# Very likely        23.892072
# dtype: float64
# -
# ## vote2020 ##
# ---- likely voter breakdown for "Joe Biden"
# Already voted      56.543714
# Likely              1.796543
# Somewhat likely     0.649863
# Very likely        37.057945
# dtype: float64
# -
# ---- likely voter breakdown for "Donald Trump"
# Already voted      47.386994
# Likely              0.534573
# Somewhat likely     1.227777
# Very likely        51.165998
# dtype: float64
# -
# ---- likely voter breakdown for "Did not vote"
# Already voted      33.574720
# Somewhat likely     9.816883
# Very likely        40.095591
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      70.339655
# Likely             28.998653
# Somewhat likely     2.467397
# Very likely        15.674640
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- likely voter breakdown for "Raphael Warnock"
# Already voted      55.069401
# Likely              1.837673
# Somewhat likely     0.483474
# Very likely        38.806995
# dtype: float64
# -
# ---- likely voter breakdown for "Undecided"
# Already voted      49.243039
# Likely              7.982621
# Somewhat likely    11.204961
# Very likely        34.833966
# dtype: float64
# -
# ---- likely voter breakdown for "Kelly Loeffler"
# Already voted      48.797723
# Likely              0.524048
# Somewhat likely     0.961272
# Very likely        49.953708
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- likely voter breakdown for "Jon Ossoff"
# Already voted      55.121173
# Likely              1.891493
# Somewhat likely     0.754022
# Very likely        38.295400
# dtype: float64
# -
# ---- likely voter breakdown for "David Perdue"
# Already voted      47.010137
# Likely              0.629835
# Somewhat likely     1.008995
# Very likely        51.794987
# dtype: float64
# -
# ---- likely voter breakdown for "Undecided"
# Already voted      67.413969
# Likely              4.395366
# Somewhat likely     5.196823
# Very likely        25.339334
# dtype: float64
# -
# <ipython-input-151-6cf45613cb4b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])

# %% [markdown]
# ## Likely Voter by Demographic

# %%
for lvx in survey['lv_likely'].unique():
    if isinstance(lvx, str):
        for var in demographics:
            print('lv_likely = {}, broken down by {}'.format(lvx, var))
            survey_ = survey[survey['lv_likely'] == lvx]
            survey_['weight'] = normalize_weights(survey_['weight'])
            print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
            print('-')
# Out:
# lv_likely = Very likely, broken down by loc_county
# Another county in Georgia    62.765224
# Cobb County, GA               5.848104
# DeKalb County, GA             9.313659
# Fulton County, GA            11.591402
# Gwinnett County, GA          10.481611
# dtype: float64
# -
# lv_likely = Very likely, broken down by gender
# Female    54.553268
# Male      45.194839
# Other      0.251894
# dtype: float64
# -
# lv_likely = Very likely, broken down by race
# Black, non-Hispanic    29.602903
# Hispanic                7.997968
# Other                   5.573242
# White, not Hispanic    56.825887
# dtype: float64
# -
# lv_likely = Very likely, broken down by education
# <ipython-input-152-59f3812805f3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# Completed graduate school      5.590623
# Graduated from college        20.620116
# Graduated from high school    29.604378
# Less than high school          9.043805
# Some college, no degree       35.141078
# dtype: float64
# -
# lv_likely = Very likely, broken down by income
# Between $100,000 and $150,000    13.137030
# Between $15,000 and $49,999      33.787391
# Between $50,000 and $74,999      17.575521
# Between $75,000 and $99,999      14.621868
# Over $150,000                    10.500993
# Under $15,000                    10.377197
# dtype: float64
# -
# lv_likely = Very likely, broken down by age
# 18-34          27.185037
# 35-54          48.142626
# 55-64          12.755983
# 65 or older    11.916354
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote2016
# Did not vote       13.818683
# Donald Trump       54.110018
# Hillary Clinton    30.134085
# Other               1.937214
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote2020
# Did not vote     1.360128
# Donald Trump    60.117670
# Joe Biden       38.163154
# Other            0.359047
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     57.062336
# Raphael Warnock    40.129362
# Undecided           2.808302
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote_ossoff_perdue
# David Perdue    58.045188
# Jon Ossoff      39.017764
# Undecided        2.937049
# dtype: float64
# -
# lv_likely = Likely, broken down by loc_county
# Another county in Georgia    79.526521
# Cobb County, GA               2.681055
# DeKalb County, GA             2.250624
# Fulton County, GA             3.569721
# Gwinnett County, GA          11.972079
# dtype: float64
# -
# lv_likely = Likely, broken down by gender
# Female               27.220053
# Male                 66.366743
# Other                 0.736731
# Prefer not to say     5.676473
# dtype: float64
# -
# lv_likely = Likely, broken down by race
# Black, non-Hispanic    11.201195
# Hispanic               16.212115
# Other                   9.374153
# White, not Hispanic    63.212537
# dtype: float64
# -
# lv_likely = Likely, broken down by education
# Completed graduate school     13.684727
# Graduated from college        20.478912
# Graduated from high school    23.138565
# Some college, no degree       42.697796
# dtype: float64
# -
# lv_likely = Likely, broken down by income
# Between $100,000 and $150,000    12.049258
# Between $15,000 and $49,999      30.013844
# Between $50,000 and $74,999      25.003875
# Between $75,000 and $99,999      16.878211
# Over $150,000                     1.591657
# Under $15,000                    14.463157
# dtype: float64
# -
# lv_likely = Likely, broken down by age
# 18-34    63.638672
# 35-54    34.769671
# 55-64     1.591657
# dtype: float64
# -
# lv_likely = Likely, broken down by vote2016
# Did not vote       46.757235
# Donald Trump        7.968878
# Hillary Clinton    38.630882
# Other               6.643006
# dtype: float64
# -
# lv_likely = Likely, broken down by vote2020
# Donald Trump    19.987395
# Joe Biden       58.874762
# Other           21.137843
# dtype: float64
# -
# lv_likely = Likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     19.049408
# Raphael Warnock    60.471291
# Undecided          20.479301
# dtype: float64
# -
# lv_likely = Likely, broken down by vote_ossoff_perdue
# David Perdue    22.461245
# Jon Ossoff      61.326641
# Undecided       16.212115
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by loc_county
# Another county in Georgia    71.983405
# Cobb County, GA               7.822288
# DeKalb County, GA            10.496064
# Fulton County, GA             4.589205
# Gwinnett County, GA           5.109037
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by gender
# Female    33.430758
# Male      66.569242
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by race
# Black, non-Hispanic     9.366257
# Other                  15.501856
# White, not Hispanic    75.131887
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by education
# Completed graduate school     11.840171
# Graduated from college         9.071311
# Graduated from high school    20.141035
# Less than high school         24.433191
# Some college, no degree       34.514292
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by income
# Between $100,000 and $150,000     1.344107
# Between $15,000 and $49,999      17.819496
# Between $50,000 and $74,999      18.084119
# Between $75,000 and $99,999      21.510525
# Under $15,000                    41.241754
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by age
# 18-34          18.290232
# 35-54          26.483304
# 55-64          20.116803
# 65 or older    35.109661
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote2016
# Did not vote       21.960088
# Donald Trump       43.600197
# Hillary Clinton    18.340251
# Other              16.099463
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote2020
# Did not vote    13.313174
# Donald Trump    57.672008
# Joe Biden       26.755290
# Other            2.259529
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     43.898836
# Raphael Warnock    19.987130
# Undecided          36.114034
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote_ossoff_perdue
# David Perdue    45.205599
# Jon Ossoff      30.713174
# Undecided       24.081227
# dtype: float64
# -
# lv_likely = Already voted, broken down by loc_county
# Another county in Georgia    78.161133
# Cobb County, GA               7.698918
# Fulton County, GA             7.128517
# Gwinnett County, GA           7.011432
# dtype: float64
# -
# lv_likely = Already voted, broken down by gender
# Female    46.124090
# Male      52.824451
# Other      1.051459
# dtype: float64
# -
# lv_likely = Already voted, broken down by race
# Black, non-Hispanic    35.343260
# Hispanic                9.534948
# Other                   4.910288
# White, not Hispanic    50.211504
# dtype: float64
# -
# lv_likely = Already voted, broken down by education
# Completed graduate school     11.759263
# Graduated from college        14.571043
# Graduated from high school    31.163545
# Less than high school         21.972956
# Some college, no degree       20.533193
# dtype: float64
# -
# lv_likely = Already voted, broken down by income
# Between $100,000 and $150,000    11.973672
# Between $15,000 and $49,999      34.165624
# Between $50,000 and $74,999      17.218224
# Between $75,000 and $99,999      10.271158
# Over $150,000                     9.736065
# Under $15,000                    16.635256
# dtype: float64
# -
# lv_likely = Already voted, broken down by age
# 18-34          17.706019
# 35-54          27.591495
# 55-64          23.730673
# 65 or older    30.971813
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote2016
# Did not vote        5.437198
# Donald Trump       44.085949
# Hillary Clinton    45.101053
# Other               5.375801
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote2020
# Did not vote     0.976297
# Donald Trump    47.727244
# Joe Biden       49.915308
# Other            1.381150
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote_warnock_loeffler
# Kelly Loeffler     47.782391
# Raphael Warnock    48.814528
# Undecided           3.403081
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote_ossoff_perdue
# David Perdue    45.160268
# Jon Ossoff      48.141621
# Undecided        6.698111
# dtype: float64
# -

# %% [markdown]
# ## Demographic by Likely Voter Score

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- likely voter score for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['lv_index'].value_counts(normalize=True) * survey_.groupby('lv_index')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- likely voter score for "Another county in Georgia"
# 0.11     0.769977
# 0.13     0.126850
# 0.40     6.010693
# 0.59     0.947111
# 0.63     1.490611
# 0.83    90.654757
# dtype: float64
# -
# ---- likely voter score for "Cobb County, GA"
# 0.13     0.665447
# 0.40    17.771933
# 0.59     0.416537
# 0.63     0.465896
# 0.83    80.680187
# dtype: float64
# -
# ---- likely voter score for "DeKalb County, GA"
# 0.40    47.587074
# 0.59     1.466251
# 0.63     0.394985
# 0.83    50.551690
# dtype: float64
# -
# ---- likely voter score for "Fulton County, GA"
# 0.40    19.874984
# 0.59     0.457714
# 0.63     0.447288
# 0.83    79.220014
# dtype: float64
# -
# ---- likely voter score for "Gwinnett County, GA"
# <ipython-input-153-530baa19b739>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# 0.11     0.732022
# 0.40    12.628564
# 0.59     0.577725
# 0.63     1.700778
# 0.83    84.360912
# dtype: float64
# -
# ## gender ##
# ---- likely voter score for "Female"
# 0.11     1.134394
# 0.13     0.217858
# 0.40    13.664324
# 0.59     0.435074
# 0.63     0.667893
# 0.83    83.880456
# dtype: float64
# -
# ---- likely voter score for "Male"
# 0.13     0.044590
# 0.40     9.216519
# 0.59     1.330490
# 0.63     1.722268
# 0.83    87.686133
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.40    61.880910
# 0.63     1.541738
# 0.83    36.577351
# dtype: float64
# -
# ---- likely voter score for "Prefer not to say"
# 0.63    100.0
# dtype: float64
# -
# ## race ##
# ---- likely voter score for "White, not Hispanic"
# 0.11     0.815908
# 0.13     0.133549
# 0.40     8.389525
# 0.59     1.306109
# 0.63     1.521718
# 0.83    87.833191
# dtype: float64
# -
# ---- likely voter score for "Black, non-Hispanic"
# 0.11     0.474538
# 0.13     0.194187
# 0.40    12.637090
# 0.59     0.092527
# 0.63     0.430768
# 0.83    86.170890
# dtype: float64
# -
# ---- likely voter score for "Hispanic"
# 0.40    24.629322
# 0.63     2.052021
# 0.83    73.318657
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.40    15.962852
# 0.59     2.816805
# 0.63     2.139938
# 0.83    79.080405
# dtype: float64
# -
# ## education ##
# ---- likely voter score for "Completed graduate school"
# 0.40    12.587841
# 0.59     1.294710
# 0.63     1.879952
# 0.83    84.237496
# dtype: float64
# -
# ---- likely voter score for "Graduated from high school"
# 0.11     1.571469
# 0.13     0.210330
# 0.40    11.132633
# 0.59     0.457468
# 0.63     0.963819
# 0.83    85.664280
# dtype: float64
# -
# ---- likely voter score for "Graduated from college"
# 0.40    17.653516
# 0.59     0.493407
# 0.63     1.399389
# 0.83    80.453688
# dtype: float64
# -
# ---- likely voter score for "Some college, no degree"
# 0.11     0.375132
# 0.13     0.244668
# 0.40    14.306007
# 0.59     0.966967
# 0.63     1.883103
# 0.83    82.224123
# dtype: float64
# -
# ---- likely voter score for "Less than high school"
# 0.59     1.731917
# 0.83    98.268083
# dtype: float64
# -
# ## income ##
# ---- likely voter score for "Between $100,000 and $150,000"
# 0.40     9.160315
# 0.59     0.110988
# 0.63     1.249966
# 0.83    89.478731
# dtype: float64
# -
# ---- likely voter score for "Between $50,000 and $74,999"
# 0.11     1.038108
# 0.40    13.163906
# 0.59     1.001651
# 0.63     1.739892
# 0.83    83.056442
# dtype: float64
# -
# ---- likely voter score for "Between $15,000 and $49,999"
# 0.11     0.674621
# 0.13     0.136151
# 0.40    16.472223
# 0.59     0.368151
# 0.63     1.067119
# 0.83    81.281736
# dtype: float64
# -
# ---- likely voter score for "Under $15,000"
# 0.11     1.124205
# 0.13     0.616585
# 0.40     8.981516
# 0.59     2.374267
# 0.63     1.317701
# 0.83    85.585726
# dtype: float64
# -
# ---- likely voter score for "Between $75,000 and $99,999"
# 0.40     5.761206
# 0.59     1.847472
# 0.63     1.821165
# 0.83    90.570156
# dtype: float64
# -
# ---- likely voter score for "Over $150,000"
# 0.40     6.564078
# 0.63     0.213826
# 0.83    93.222096
# dtype: float64
# -
# ## age ##
# ---- likely voter score for "18-34"
# 0.11     1.615868
# 0.13     0.077633
# 0.40    27.335751
# 0.59     0.580155
# 0.63     2.875307
# 0.83    67.515286
# dtype: float64
# -
# ---- likely voter score for "35-54"
# 0.11     0.364638
# 0.13     0.133384
# 0.40    10.045774
# 0.59     0.600875
# 0.63     1.211082
# 0.83    87.644248
# dtype: float64
# -
# ---- likely voter score for "55-64"
# 0.13     0.378532
# 0.40     2.413916
# 0.59     0.821862
# 0.63     0.119319
# 0.83    96.266370
# dtype: float64
# -
# ---- likely voter score for "65 or older"
# 0.40     1.022045
# 0.59     1.786609
# 0.83    97.191346
# dtype: float64
# -
# ## vote2016 ##
# ---- likely voter score for "Hillary Clinton"
# 0.40    14.662443
# 0.59     0.463737
# 0.63     1.227149
# 0.83    83.646670
# dtype: float64
# -
# ---- likely voter score for "Did not vote"
# 0.11     4.553675
# 0.13     1.043763
# 0.40    31.536471
# 0.59     0.677924
# 0.63     4.605375
# 0.83    57.582791
# dtype: float64
# -
# ---- likely voter score for "Donald Trump"
# 0.40     3.582630
# 0.59     0.986039
# 0.63     0.226412
# 0.83    95.204919
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.40    11.272938
# 0.59     4.278954
# 0.63     2.218129
# 0.83    82.229979
# dtype: float64
# -
# ## vote2020 ##
# ---- likely voter score for "Joe Biden"
# 0.40    18.955602
# 0.59     0.548348
# 0.63     1.515905
# 0.83    78.980145
# dtype: float64
# -
# ---- likely voter score for "Donald Trump"
# 0.40     3.034379
# 0.59     1.186780
# 0.63     0.516722
# 0.83    95.262119
# dtype: float64
# -
# ---- likely voter score for "Did not vote"
# 0.11    33.905971
# 0.13     7.771699
# 0.40    58.322329
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.40     9.047475
# 0.59     1.910243
# 0.63    22.450570
# 0.83    66.591712
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- likely voter score for "Raphael Warnock"
# 0.11     0.399019
# 0.13     0.128395
# 0.40    19.481562
# 0.59     0.276145
# 0.63     1.537645
# 0.83    78.177233
# dtype: float64
# -
# ---- likely voter score for "Undecided"
# 0.11     5.412510
# 0.13     1.922145
# 0.40     7.376875
# 0.59     8.037821
# 0.63     7.095663
# 0.83    70.154987
# dtype: float64
# -
# ---- likely voter score for "Kelly Loeffler"
# 0.11     0.396656
# 0.40     4.099049
# 0.59     0.929060
# 0.63     0.506487
# 0.83    94.068747
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- likely voter score for "Jon Ossoff"
# 0.11     0.404265
# 0.13     0.130083
# 0.40    19.617425
# 0.59     0.499724
# 0.63     1.579896
# 0.83    77.768607
# dtype: float64
# -
# ---- likely voter score for "David Perdue"
# 0.11     0.403080
# 0.40     4.201285
# 0.59     0.972209
# 0.63     0.606872
# 0.83    93.816554
# dtype: float64
# -
# ---- likely voter score for "Undecided"
# 0.11     3.909436
# 0.13     1.388358
# 0.40     6.164368
# 0.59     3.408710
# 0.63     4.057261
# 0.83    81.071868
# dtype: float64
# -

# %% [markdown]
# ## Likely Voter Score by Demographic

# %%
for lvx in sorted(survey['lv_index'].unique())[::-1]:
    for var in demographics:
        print('lv_index = {}, broken down by {}'.format(lvx, var))
        survey_ = survey[survey['lv_index'] == lvx]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# lv_index = 0.83, broken down by loc_county
# Another county in Georgia    70.969833
# Cobb County, GA               6.812702
# DeKalb County, GA             4.226622
# Fulton County, GA             9.277217
# Gwinnett County, GA           8.713627
# dtype: float64
# -
# lv_index = 0.83, broken down by gender
# Female    50.162415
# Male      49.581110
# Other      0.256476
# dtype: float64
# -
# lv_index = 0.83, broken down by race
# Black, non-Hispanic    32.878895
# Hispanic                8.499787
# Other                   5.083179
# White, not Hispanic    53.538139
# dtype: float64
# -
# lv_index = 0.83, broken down by education
# Completed graduate school      8.997678
# Graduated from college        17.276275
# Graduated from high school    30.177008
# Less than high school         16.192179
# Some college, no degree       27.356860
# dtype: float64
# -
# lv_index = 0.83, broken down by income
# Between $100,000 and $150,000    12.656617
# Between $15,000 and $49,999      33.545749
# Between $50,000 and $74,999      17.514344
# Between $75,000 and $99,999      12.316798
# Over $150,000                    10.182240
# Under $15,000                    13.784251
# dtype: float64
# -
# lv_index = 0.83, broken down by age
# 18-34          21.926769
# 35-54          36.922082
# 55-64          18.842960
# 65 or older    22.308188
# dtype: float64
# -
# lv_index = 0.83, broken down by vote2016
# Did not vote        8.578516
# Donald Trump       49.169238
# Hillary Clinton    38.638617
# Other               3.613629
# dtype: float64
# -
# lv_index = 0.83, broken down by vote2020
# Donald Trump    54.069810
# Joe Biden       45.010187
# Other            0.920003
# dtype: float64
# -
# lv_index = 0.83, broken down by vote_warnock_loeffler
# Kelly Loeffler     51.915139
# Raphael Warnock    45.113768
# Undecided           2.971094
# dtype: float64
# -
# lv_index = 0.83, broken down by vote_ossoff_perdue
# David Perdue    50.950895
# Jon Ossoff      44.295615
# Undecided        4.753490
# dtype: float64
# -
# lv_index = 0.63, broken down by loc_county
# Another county in Georgia    79.526521
# Cobb County, GA               2.681055
# DeKalb County, GA             2.250624
# Fulton County, GA             3.569721
# Gwinnett County, GA          11.972079
# dtype: float64
# -
# lv_index = 0.63, broken down by gender
# Female               27.220053
# Male                 66.366743
# Other                 0.736731
# Prefer not to say     5.676473
# dtype: float64
# -
# lv_index = 0.63, broken down by race
# Black, non-Hispanic    11.201195
# Hispanic               16.212115
# Other                   9.374153
# White, not Hispanic    63.212537
# dtype: float64
# -
# lv_index = 0.63, broken down by education
# Completed graduate school     13.684727
# Graduated from college        20.478912
# Graduated from high school    23.138565
# Some college, no degree       42.697796
# dtype: float64
# -
# lv_index = 0.63, broken down by income
# Between $100,000 and $150,000    12.049258
# Between $15,000 and $49,999      30.013844
# Between $50,000 and $74,999      25.003875
# Between $75,000 and $99,999      16.878211
# Over $150,000                     1.591657
# Under $15,000                    14.463157
# dtype: float64
# -
# lv_index = 0.63, broken down by age
# 18-34    63.638672
# 35-54    34.769671
# 55-64     1.591657
# dtype: float64
# -
# lv_index = 0.63, broken down by vote2016
# Did not vote       46.757235
# Donald Trump        7.968878
# Hillary Clinton    38.630882
# Other               6.643006
# dtype: float64
# -
# lv_index = 0.63, broken down by vote2020
# Donald Trump    19.987395
# Joe Biden       58.874762
# Other           21.137843
# dtype: float64
# -
# lv_index = 0.63, broken down by vote_warnock_loeffler
# Kelly Loeffler     19.049408
# Raphael Warnock    60.471291
# Undecided          20.479301
# dtype: float64
# -
# lv_index = 0.63, broken down by vote_ossoff_perdue
# David Perdue    22.461245
# Jon Ossoff      61.326641
# Undecided       16.212115
# dtype: float64
# -
# lv_index = 0.59, broken down by loc_county
# Another county in Georgia    73.230427
# Cobb County, GA               3.473869
# DeKalb County, GA            12.108026
# Fulton County, GA             5.294006
# Gwinnett County, GA           5.893672
# dtype: float64
# -
# lv_index = 0.59, broken down by gender
# Female    25.697359
# Male      74.302641
# dtype: float64
# -
# lv_index = 0.59, broken down by race
# Black, non-Hispanic     3.486833
# Other                  17.882598
# White, not Hispanic    78.630569
# dtype: float64
# -
# lv_index = 0.59, broken down by education
# Completed graduate school     13.658559
# Graduated from college        10.464463
# Graduated from high school    15.916379
# Less than high school         28.185588
# Some college, no degree       31.775012
# dtype: float64
# -
# lv_index = 0.59, broken down by income
# Between $100,000 and $150,000     1.550532
# Between $15,000 and $49,999      15.006426
# Between $50,000 and $74,999      20.861438
# Between $75,000 and $99,999      24.814064
# Under $15,000                    37.767539
# dtype: float64
# -
# lv_index = 0.59, broken down by age
# 18-34          18.609045
# 35-54          25.000803
# 55-64          15.888425
# 65 or older    40.501727
# dtype: float64
# -
# lv_index = 0.59, broken down by vote2016
# Did not vote        9.974888
# Donald Trump       50.296221
# Hillary Clinton    21.156907
# Other              18.571984
# dtype: float64
# -
# lv_index = 0.59, broken down by vote2020
# Donald Trump    66.529149
# Joe Biden       30.864309
# Other            2.606542
# dtype: float64
# -
# lv_index = 0.59, broken down by vote_warnock_loeffler
# Kelly Loeffler     50.640724
# Raphael Warnock    15.738837
# Undecided          33.620439
# dtype: float64
# -
# lv_index = 0.59, broken down by vote_ossoff_perdue
# David Perdue    52.148176
# Jon Ossoff      28.112164
# Undecided       19.739660
# dtype: float64
# -
# lv_index = 0.4, broken down by loc_county
# Another county in Georgia    34.056393
# Cobb County, GA              10.861207
# DeKalb County, GA            28.796368
# Fulton County, GA            16.845368
# Gwinnett County, GA           9.440665
# dtype: float64
# -
# lv_index = 0.4, broken down by gender
# Female    59.142101
# Male      37.717523
# Other      3.140376
# dtype: float64
# -
# lv_index = 0.4, broken down by race
# Black, non-Hispanic    34.897526
# Hispanic               20.665071
# Other                   7.426222
# White, not Hispanic    37.011181
# dtype: float64
# -
# lv_index = 0.4, broken down by education
# Completed graduate school      9.731217
# Graduated from college        27.436348
# Graduated from high school    28.383453
# Some college, no degree       34.448981
# dtype: float64
# -
# lv_index = 0.4, broken down by income
# Between $100,000 and $150,000     9.377761
# Between $15,000 and $49,999      49.202558
# Between $50,000 and $74,999      20.090756
# Between $75,000 and $99,999       5.670444
# Over $150,000                     5.189066
# Under $15,000                    10.469415
# dtype: float64
# -
# lv_index = 0.4, broken down by age
# 18-34          64.253158
# 35-54          30.629301
# 55-64           3.419698
# 65 or older     1.697843
# dtype: float64
# -
# lv_index = 0.4, broken down by vote2016
# Did not vote       34.003488
# Donald Trump       13.391432
# Hillary Clinton    49.019648
# Other               3.585432
# dtype: float64
# -
# lv_index = 0.4, broken down by vote2020
# Did not vote     8.445611
# Donald Trump    12.465090
# Joe Biden       78.184636
# Other            0.904664
# dtype: float64
# -
# lv_index = 0.4, broken down by vote_warnock_loeffler
# Kelly Loeffler     16.372789
# Raphael Warnock    81.366104
# Undecided           2.261107
# dtype: float64
# -
# lv_index = 0.4, broken down by vote_ossoff_perdue
# David Perdue    16.513740
# Jon Ossoff      80.870355
# Undecided        2.615904
# dtype: float64
# -
# lv_index = 0.13, broken down by loc_county
# Another county in Georgia    63.863601
# Cobb County, GA              36.136399
# dtype: float64
# -
# lv_index = 0.13, broken down by gender
# Female    83.785678
# Male      16.214322
# dtype: float64
# -
# lv_index = 0.13, broken down by race
# Black, non-Hispanic    47.649279
# White, not Hispanic    52.350721
# dtype: float64
# -
# lv_index = 0.13, broken down by education
# Graduated from high school    47.649279
# Some college, no degree       52.350721
# dtype: float64
# -
# lv_index = 0.13, broken down by income
# Between $15,000 and $49,999    36.136399
# Under $15,000                  63.863601
# dtype: float64
# -
# lv_index = 0.13, broken down by age
# 18-34    16.214322
# 35-54    36.136399
# 55-64    47.649279
# dtype: float64
# -
# lv_index = 0.13, broken down by vote2016
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.13, broken down by vote2020
# Did not vote    100.0
# dtype: float64
# <ipython-input-154-1e9494554290>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# -
# lv_index = 0.13, broken down by vote_warnock_loeffler
# Raphael Warnock    47.649279
# Undecided          52.350721
# dtype: float64
# -
# lv_index = 0.13, broken down by vote_ossoff_perdue
# Jon Ossoff    47.649279
# Undecided     52.350721
# dtype: float64
# -
# lv_index = 0.11, broken down by loc_county
# Another county in Georgia    88.854486
# Gwinnett County, GA          11.145514
# dtype: float64
# -
# lv_index = 0.11, broken down by gender
# Female    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by race
# Black, non-Hispanic    26.689842
# White, not Hispanic    73.310158
# dtype: float64
# -
# lv_index = 0.11, broken down by education
# Graduated from high school    81.602022
# Some college, no degree       18.397978
# dtype: float64
# -
# lv_index = 0.11, broken down by income
# Between $15,000 and $49,999    41.041444
# Between $50,000 and $74,999    32.268714
# Under $15,000                  26.689842
# dtype: float64
# -
# lv_index = 0.11, broken down by age
# 18-34    77.356534
# 35-54    22.643466
# dtype: float64
# -
# lv_index = 0.11, broken down by vote2016
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by vote2020
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by vote_warnock_loeffler
# Kelly Loeffler     32.268714
# Raphael Warnock    33.942306
# Undecided          33.788980
# dtype: float64
# -
# lv_index = 0.11, broken down by vote_ossoff_perdue
# David Perdue    32.268714
# Jon Ossoff      33.942306
# Undecided       33.788980
# dtype: float64
# -

# %% [markdown]
# ## Demographic by Enthusiasm

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- enthusiasm breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['enthusiasm'].value_counts(normalize=True) * survey_.groupby('enthusiasm')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- enthusiasm breakdown for "Another county in Georgia"
# About the same       13.879291
# Less enthusiastic    14.862420
# More enthusiastic    71.258289
# dtype: float64
# -
# ---- enthusiasm breakdown for "Cobb County, GA"
# About the same       23.389811
# Less enthusiastic    18.848827
# More enthusiastic    57.761363
# dtype: float64
# -
# ---- enthusiasm breakdown for "DeKalb County, GA"
# About the same       31.642241
# Less enthusiastic     1.459160
# More enthusiastic    66.898599
# dtype: float64
# -
# ---- enthusiasm breakdown for "Fulton County, GA"
# About the same       13.616859
# Less enthusiastic    10.623790
# More enthusiastic    75.759351
# dtype: float64
# -
# ---- enthusiasm breakdown for "Gwinnett County, GA"
# About the same       11.923260
# Less enthusiastic     8.216472
# More enthusiastic    79.860268
# dtype: float64
# -
# ## gender ##
# ---- enthusiasm breakdown for "Female"
# About the same       17.127393
# Less enthusiastic    15.551277
# More enthusiastic    67.321330
# dtype: float64
# -
# ---- enthusiasm breakdown for "Male"
# About the same       14.093594
# Less enthusiastic    10.836732
# More enthusiastic    75.069675
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same        2.486847
# Less enthusiastic     2.004744
# More enthusiastic    95.508409
# dtype: float64
# -
# ---- enthusiasm breakdown for "Prefer not to say"
# About the same    100.0
# dtype: float64
# -
# ## race ##
# ---- enthusiasm breakdown for "White, not Hispanic"
# About the same       14.797807
# Less enthusiastic    14.305007
# More enthusiastic    70.897186
# dtype: float64
# -
# ---- enthusiasm breakdown for "Black, non-Hispanic"
# About the same       15.773796
# Less enthusiastic    10.348366
# More enthusiastic    73.877838
# dtype: float64
# -
# ---- enthusiasm breakdown for "Hispanic"
# About the same       22.644224
# Less enthusiastic    16.811334
# More enthusiastic    60.544442
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same       10.092946
# Less enthusiastic    12.829489
# More enthusiastic    77.077565
# dtype: float64
# -
# ## education ##
# ---- enthusiasm breakdown for "Completed graduate school"
# About the same       18.311781
# Less enthusiastic     7.138583
# More enthusiastic    74.549636
# dtype: float64
# -
# ---- enthusiasm breakdown for "Graduated from high school"
# About the same       17.096542
# Less enthusiastic    14.654580
# More enthusiastic    68.248878
# dtype: float64
# -
# ---- enthusiasm breakdown for "Graduated from college"
# About the same       13.009467
# Less enthusiastic    12.960613
# More enthusiastic    74.029921
# dtype: float64
# -
# ---- enthusiasm breakdown for "Some college, no degree"
# About the same       17.075455
# Less enthusiastic    16.064305
# More enthusiastic    66.860240
# dtype: float64
# -
# ---- enthusiasm breakdown for "Less than high school"
# About the same       11.282163
# Less enthusiastic     8.428620
# More enthusiastic    80.289217
# dtype: float64
# -
# ## income ##
# ---- enthusiasm breakdown for "Between $100,000 and $150,000"
# About the same        9.889345
# Less enthusiastic     5.559030
# More enthusiastic    84.551625
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $50,000 and $74,999"
# About the same       20.126390
# Less enthusiastic    15.062857
# More enthusiastic    64.810753
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $15,000 and $49,999"
# About the same       18.468405
# Less enthusiastic    11.503873
# More enthusiastic    70.027722
# dtype: float64
# -
# ---- enthusiasm breakdown for "Under $15,000"
# About the same       11.564063
# Less enthusiastic    17.021605
# More enthusiastic    71.414331
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $75,000 and $99,999"
# About the same       16.488690
# Less enthusiastic    19.998602
# More enthusiastic    63.512708
# dtype: float64
# -
# ---- enthusiasm breakdown for "Over $150,000"
# About the same        8.629148
# Less enthusiastic    11.627758
# More enthusiastic    79.743093
# dtype: float64
# -
# ## age ##
# ---- enthusiasm breakdown for "18-34"
# About the same       20.273052
# Less enthusiastic     7.830951
# More enthusiastic    71.895997
# dtype: float64
# -
# ---- enthusiasm breakdown for "35-54"
# About the same       18.011436
# Less enthusiastic    16.112237
# More enthusiastic    65.876327
# dtype: float64
# -
# ---- enthusiasm breakdown for "55-64"
# About the same        5.614022
# Less enthusiastic    19.425756
# More enthusiastic    74.960222
# dtype: float64
# -
# ---- enthusiasm breakdown for "65 or older"
# About the same       13.252120
# Less enthusiastic    10.056917
# More enthusiastic    76.690964
# dtype: float64
# -
# ## vote2016 ##
# ---- enthusiasm breakdown for "Hillary Clinton"
# About the same       13.370779
# Less enthusiastic     5.808944
# More enthusiastic    80.820277
# dtype: float64
# -
# ---- enthusiasm breakdown for "Did not vote"
# About the same       22.214289
# Less enthusiastic    12.446033
# More enthusiastic    65.339678
# dtype: float64
# -
# ---- enthusiasm breakdown for "Donald Trump"
# About the same       15.996731
# Less enthusiastic    17.788327
# More enthusiastic    66.214942
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same       12.856872
# Less enthusiastic    39.075646
# More enthusiastic    48.067482
# dtype: float64
# -
# ## vote2020 ##
# ---- enthusiasm breakdown for "Joe Biden"
# About the same       14.844067
# Less enthusiastic     7.477369
# More enthusiastic    77.678564
# dtype: float64
# -
# ---- enthusiasm breakdown for "Donald Trump"
# About the same       15.408287
# Less enthusiastic    19.065756
# More enthusiastic    65.525956
# dtype: float64
# -
# ---- enthusiasm breakdown for "Did not vote"
# About the same       39.906873
# Less enthusiastic     4.950407
# More enthusiastic    55.142720
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same       22.350986
# Less enthusiastic    18.797949
# More enthusiastic    58.851064
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- enthusiasm breakdown for "Raphael Warnock"
# About the same       14.634853
# Less enthusiastic     9.149516
# More enthusiastic    76.215630
# dtype: float64
# -
# ---- enthusiasm breakdown for "Undecided"
# About the same       30.290038
# Less enthusiastic    25.120350
# More enthusiastic    44.589612
# dtype: float64
# -
# ---- enthusiasm breakdown for "Kelly Loeffler"
# About the same       15.554367
# Less enthusiastic    16.484963
# More enthusiastic    67.960669
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- enthusiasm breakdown for "Jon Ossoff"
# About the same       15.015860
# Less enthusiastic     9.167319
# More enthusiastic    75.816821
# dtype: float64
# -
# ---- enthusiasm breakdown for "David Perdue"
# About the same       15.847873
# Less enthusiastic    16.878905
# More enthusiastic    67.273221
# dtype: float64
# -
# ---- enthusiasm breakdown for "Undecided"
# About the same       19.660608
# Less enthusiastic    17.963603
# More enthusiastic    62.375789
# dtype: float64
# -
# <ipython-input-155-051615e720f2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])

# %% [markdown]
# ## Enthusiasm by Demographic

# %%
for enth in sorted(survey['enthusiasm'].unique())[::-1]:
    for var in demographics:
        print('enthusiasm = {}, broken down by {}'.format(enth, var))
        survey_ = survey[survey['enthusiasm'] == enth]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# enthusiasm = More enthusiastic, broken down by loc_county
# Another county in Georgia    66.907393
# Cobb County, GA               5.849860
# DeKalb County, GA             6.708576
# Fulton County, GA            10.640807
# Gwinnett County, GA           9.893364
# dtype: float64
# <ipython-input-156-2d28f7f77c34>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# -
# enthusiasm = More enthusiastic, broken down by gender
# Female    48.286517
# Male      50.910270
# Other      0.803214
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by race
# Black, non-Hispanic    33.808535
# Hispanic                8.418279
# Other                   5.942238
# White, not Hispanic    51.830948
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by education
# Completed graduate school      9.550499
# Graduated from college        19.066325
# Graduated from high school    28.835499
# Less than high school         15.867393
# Some college, no degree       26.680285
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by income
# Between $100,000 and $150,000    14.344167
# Between $15,000 and $49,999      34.663313
# Between $50,000 and $74,999      16.391669
# Between $75,000 and $99,999      10.359263
# Over $150,000                    10.446555
# Under $15,000                    13.795033
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by age
# 18-34          28.004820
# 35-54          33.284933
# 55-64          17.597904
# 65 or older    21.112343
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote2016
# Did not vote       11.674868
# Donald Trump       41.015276
# Hillary Clinton    44.776360
# Other               2.533497
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote2020
# Did not vote     1.323272
# Donald Trump    44.607052
# Joe Biden       53.094510
# Other            0.975167
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote_warnock_loeffler
# Kelly Loeffler     44.984391
# Raphael Warnock    52.750719
# Undecided           2.264890
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote_ossoff_perdue
# David Perdue    43.819771
# Jon Ossoff      51.793771
# Undecided        4.386458
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by loc_county
# Another county in Georgia    75.349612
# Cobb County, GA              10.307305
# DeKalb County, GA             0.790076
# Fulton County, GA             8.056948
# Gwinnett County, GA           5.496059
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by gender
# Female    60.227111
# Male      39.681855
# Other      0.091034
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by race
# Black, non-Hispanic    25.570355
# Hispanic               12.621297
# Other                   5.340528
# White, not Hispanic    56.467820
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by education
# Completed graduate school      4.937935
# Graduated from college        18.023454
# Graduated from high school    33.431672
# Less than high school          8.994098
# Some college, no degree       34.612842
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by income
# Between $100,000 and $150,000     5.092196
# Between $15,000 and $49,999      30.746587
# Between $50,000 and $74,999      20.570092
# Between $75,000 and $99,999      17.612486
# Over $150,000                     8.224866
# Under $15,000                    17.753773
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by age
# 18-34          16.470067
# 35-54          43.956887
# 55-64          24.624124
# 65 or older    14.948922
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote2016
# Did not vote       12.007669
# Donald Trump       59.494595
# Hillary Clinton    17.377144
# Other              11.120592
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote2020
# Did not vote     0.641438
# Donald Trump    70.080465
# Joe Biden       27.596246
# Other            1.681852
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote_warnock_loeffler
# Kelly Loeffler     58.917589
# Raphael Warnock    34.192846
# Undecided           6.889565
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote_ossoff_perdue
# David Perdue    59.364242
# Jon Ossoff      33.814819
# Undecided        6.820939
# dtype: float64
# -
# enthusiasm = About the same, broken down by loc_county
# Another county in Georgia    59.334345
# Cobb County, GA              10.785365
# DeKalb County, GA            14.447100
# Fulton County, GA             8.707940
# Gwinnett County, GA           6.725249
# dtype: float64
# -
# enthusiasm = About the same, broken down by gender
# Female               55.932545
# Male                 43.517381
# Other                 0.095222
# Prefer not to say     0.454852
# dtype: float64
# -
# enthusiasm = About the same, broken down by race
# Black, non-Hispanic    32.866128
# Hispanic               14.335295
# Other                   3.542747
# White, not Hispanic    49.255830
# dtype: float64
# -
# enthusiasm = About the same, broken down by education
# Completed graduate school     10.680983
# Graduated from college        15.255250
# Graduated from high school    32.888220
# Less than high school         10.151749
# Some college, no degree       31.023798
# dtype: float64
# -
# enthusiasm = About the same, broken down by income
# Between $100,000 and $150,000     7.638728
# Between $15,000 and $49,999      41.622637
# Between $50,000 and $74,999      23.176195
# Between $75,000 and $99,999      12.244880
# Over $150,000                     5.146928
# Under $15,000                    10.170633
# dtype: float64
# -
# enthusiasm = About the same, broken down by age
# 18-34          35.954012
# 35-54          41.434946
# 55-64           6.000733
# 65 or older    16.610310
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote2016
# Did not vote       18.072055
# Donald Trump       45.115006
# Hillary Clinton    33.727589
# Other               3.085350
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote2020
# Did not vote     4.360222
# Donald Trump    47.757837
# Joe Biden       46.195693
# Other            1.686247
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote_warnock_loeffler
# Kelly Loeffler     46.876662
# Raphael Warnock    46.118254
# Undecided           7.005083
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote_ossoff_perdue
# David Perdue    47.000125
# Jon Ossoff      46.704885
# Undecided        6.294990
# dtype: float64
# -

# %% [markdown]
# ## Demographic by Vote Method

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- vote method breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print(survey_['vote_method'].value_counts(normalize=True) * survey_.groupby('vote_method')['lv_weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- vote method breakdown for "Another county in Georgia"
# Absentee by mail               33.547243
# Early vote in person           47.652757
# I will vote on election day    18.799999
# dtype: float64
# -
# ---- vote method breakdown for "Cobb County, GA"
# Absentee by mail               50.716129
# Early vote in person           33.862338
# I will vote on election day    15.421533
# dtype: float64
# -
# ---- vote method breakdown for "DeKalb County, GA"
# Absentee by mail               54.444071
# Early vote in person           31.181514
# I will vote on election day    14.374415
# dtype: float64
# -
# ---- vote method breakdown for "Fulton County, GA"
# Absentee by mail               32.939703
# Early vote in person           46.869472
# I will vote on election day    20.190825
# dtype: float64
# -
# ---- vote method breakdown for "Gwinnett County, GA"
# Absentee by mail               36.713096
# Early vote in person           44.471178
# I will vote on election day    18.815726
# dtype: float64
# -
# ## gender ##
# ---- vote method breakdown for "Female"
# Absentee by mail               35.613867
# Early vote in person           46.419236
# I will vote on election day    17.966897
# dtype: float64
# -
# ---- vote method breakdown for "Male"
# Absentee by mail               36.82372
# Early vote in person           44.05730
# I will vote on election day    19.11898
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail        31.9097
# Early vote in person    68.0903
# dtype: float64
# -
# ---- vote method breakdown for "Prefer not to say"
# Early vote in person    100.0
# dtype: float64
# -
# ## race ##
# ---- vote method breakdown for "White, not Hispanic"
# Absentee by mail               34.162652
# Early vote in person           41.680642
# I will vote on election day    24.156706
# dtype: float64
# -
# ---- vote method breakdown for "Black, non-Hispanic"
# Absentee by mail               41.399893
# Early vote in person           48.809918
# I will vote on election day     9.790188
# dtype: float64
# <ipython-input-157-a76a51f2b65b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# -
# ---- vote method breakdown for "Hispanic"
# Absentee by mail               32.113756
# Early vote in person           50.021780
# I will vote on election day    17.864464
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               31.179864
# Early vote in person           53.050254
# I will vote on election day    15.769882
# dtype: float64
# -
# ## education ##
# ---- vote method breakdown for "Completed graduate school"
# Absentee by mail               43.031612
# Early vote in person           46.533744
# I will vote on election day    10.434644
# dtype: float64
# -
# ---- vote method breakdown for "Graduated from high school"
# Absentee by mail               43.194551
# Early vote in person           38.075494
# I will vote on election day    18.729955
# dtype: float64
# -
# ---- vote method breakdown for "Graduated from college"
# Absentee by mail               28.327088
# Early vote in person           52.223197
# I will vote on election day    19.449714
# dtype: float64
# -
# ---- vote method breakdown for "Some college, no degree"
# Absentee by mail               27.641946
# Early vote in person           50.504345
# I will vote on election day    21.853708
# dtype: float64
# -
# ---- vote method breakdown for "Less than high school"
# Absentee by mail               43.191265
# Early vote in person           41.605567
# I will vote on election day    15.203168
# dtype: float64
# -
# ## income ##
# ---- vote method breakdown for "Between $100,000 and $150,000"
# Absentee by mail               29.857404
# Early vote in person           51.794118
# I will vote on election day    18.348477
# dtype: float64
# -
# ---- vote method breakdown for "Between $50,000 and $74,999"
# Absentee by mail               27.184779
# Early vote in person           58.269876
# I will vote on election day    14.545345
# dtype: float64
# -
# ---- vote method breakdown for "Between $15,000 and $49,999"
# Absentee by mail               45.364313
# Early vote in person           39.190540
# I will vote on election day    15.445148
# dtype: float64
# -
# ---- vote method breakdown for "Under $15,000"
# Absentee by mail               53.223618
# Early vote in person           30.901765
# I will vote on election day    15.874617
# dtype: float64
# -
# ---- vote method breakdown for "Between $75,000 and $99,999"
# Absentee by mail               18.948836
# Early vote in person           57.729398
# I will vote on election day    23.321765
# dtype: float64
# -
# ---- vote method breakdown for "Over $150,000"
# Absentee by mail               25.292396
# Early vote in person           40.788933
# I will vote on election day    33.918671
# dtype: float64
# -
# ## age ##
# ---- vote method breakdown for "18-34"
# Absentee by mail               38.915137
# Early vote in person           50.502691
# I will vote on election day    10.582172
# dtype: float64
# -
# ---- vote method breakdown for "35-54"
# Absentee by mail               24.781569
# Early vote in person           46.652472
# I will vote on election day    28.565958
# dtype: float64
# -
# ---- vote method breakdown for "55-64"
# Absentee by mail               34.091713
# Early vote in person           50.047131
# I will vote on election day    15.861156
# dtype: float64
# -
# ---- vote method breakdown for "65 or older"
# Absentee by mail               54.492230
# Early vote in person           33.118958
# I will vote on election day    12.388812
# dtype: float64
# -
# ## vote2016 ##
# ---- vote method breakdown for "Hillary Clinton"
# Absentee by mail               52.196838
# Early vote in person           43.749525
# I will vote on election day     4.053637
# dtype: float64
# -
# ---- vote method breakdown for "Did not vote"
# Absentee by mail               27.771261
# Early vote in person           54.654961
# I will vote on election day    17.573779
# dtype: float64
# -
# ---- vote method breakdown for "Donald Trump"
# Absentee by mail               24.117596
# Early vote in person           44.640380
# I will vote on election day    31.242024
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               42.339688
# Early vote in person           45.373640
# I will vote on election day    12.286673
# dtype: float64
# -
# ## vote2020 ##
# ---- vote method breakdown for "Joe Biden"
# Absentee by mail               49.619800
# Early vote in person           43.623187
# I will vote on election day     6.757013
# dtype: float64
# -
# ---- vote method breakdown for "Donald Trump"
# Absentee by mail               24.361949
# Early vote in person           46.627767
# I will vote on election day    29.010284
# dtype: float64
# -
# ---- vote method breakdown for "Did not vote"
# Absentee by mail               38.617575
# Early vote in person           47.265192
# I will vote on election day    14.117233
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               10.121143
# Early vote in person           61.237522
# I will vote on election day    28.641334
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- vote method breakdown for "Raphael Warnock"
# Absentee by mail               48.781669
# Early vote in person           44.706190
# I will vote on election day     6.512141
# dtype: float64
# -
# ---- vote method breakdown for "Undecided"
# Absentee by mail               31.332271
# Early vote in person           40.410346
# I will vote on election day    28.257383
# dtype: float64
# -
# ---- vote method breakdown for "Kelly Loeffler"
# Absentee by mail               24.418784
# Early vote in person           46.371147
# I will vote on election day    29.210069
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- vote method breakdown for "Jon Ossoff"
# Absentee by mail               48.140639
# Early vote in person           44.970263
# I will vote on election day     6.889098
# dtype: float64
# -
# ---- vote method breakdown for "David Perdue"
# Absentee by mail               25.335168
# Early vote in person           44.996022
# I will vote on election day    29.668809
# dtype: float64
# -
# ---- vote method breakdown for "Undecided"
# Absentee by mail               29.634256
# Early vote in person           53.208302
# I will vote on election day    17.157443
# dtype: float64
# -

# %% [markdown]
# ## Vote Method by Demographic

# %%
for method in sorted(survey['vote_method'].unique())[::-1]:
    for var in demographics:
        print('vote method = "{}", broken down by {}'.format(method, var))
        survey_ = survey[survey['vote_method'] == method]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# vote method = "I will vote on election day", broken down by loc_county
# Another county in Georgia    90.314362
# Cobb County, GA               7.828920
# DeKalb County, GA             5.727782
# Fulton County, GA            13.354684
# Gwinnett County, GA          11.376176
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by gender
# Female    63.052638
# Male      65.549286
# dtype: float64
# <ipython-input-158-8d3ff2d10575>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# -
# vote method = "I will vote on election day", broken down by race
# Black, non-Hispanic    22.076401
# Hispanic               11.341858
# Other                   5.849370
# White, not Hispanic    89.334295
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by education
# Completed graduate school      6.663138
# Graduated from college        24.116917
# Graduated from high school    38.727664
# Less than high school         16.029835
# Some college, no degree       43.064370
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by income
# Between $100,000 and $150,000    15.612657
# Between $15,000 and $49,999      36.720956
# Between $50,000 and $74,999      17.893626
# Between $75,000 and $99,999      19.995126
# Over $150,000                    22.697814
# Under $15,000                    15.681744
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by age
# 18-34          18.678473
# 35-54          72.277893
# 55-64          19.650058
# 65 or older    17.995500
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote2016
# Did not vote        13.437723
# Donald Trump       100.582428
# Hillary Clinton     11.089190
# Other                3.492583
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote2020
# Did not vote      1.251333
# Donald Trump    102.901201
# Joe Biden        22.107345
# Other             2.342046
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote_warnock_loeffler
# Kelly Loeffler     100.133306
# Raphael Warnock     21.598049
# Undecided            6.870569
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote_ossoff_perdue
# David Perdue    100.048658
# Jon Ossoff       22.321988
# Undecided         6.231278
# dtype: float64
# -
# vote method = "Early vote in person", broken down by loc_county
# Another county in Georgia    71.649354
# Cobb County, GA               5.183633
# DeKalb County, GA             5.436235
# Fulton County, GA            10.752468
# Gwinnett County, GA           9.169359
# dtype: float64
# -
# vote method = "Early vote in person", broken down by gender
# Female               52.675973
# Male                 48.303952
# Other                 1.050493
# Prefer not to say     0.160631
# dtype: float64
# -
# vote method = "Early vote in person", broken down by race
# Black, non-Hispanic    34.936758
# Hispanic               11.648049
# Other                   6.379536
# White, not Hispanic    49.226707
# dtype: float64
# -
# vote method = "Early vote in person", broken down by education
# Completed graduate school      9.305914
# Graduated from college        21.878926
# Graduated from high school    25.775349
# Less than high school         13.154655
# Some college, no degree       32.076205
# dtype: float64
# -
# vote method = "Early vote in person", broken down by income
# Between $100,000 and $150,000    13.799301
# Between $15,000 and $49,999      31.502989
# Between $50,000 and $74,999      23.494694
# Between $75,000 and $99,999      15.241064
# Over $150,000                     8.860700
# Under $15,000                     9.292299
# dtype: float64
# -
# vote method = "Early vote in person", broken down by age
# 18-34          30.551488
# 35-54          38.010798
# 55-64          18.940912
# 65 or older    14.687851
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote2016
# Did not vote       15.256716
# Donald Trump       44.222833
# Hillary Clinton    38.978018
# Other               3.733483
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote2020
# Did not vote     2.002761
# Donald Trump    50.832976
# Joe Biden       47.720550
# Other            1.634762
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote_warnock_loeffler
# Kelly Loeffler     49.512691
# Raphael Warnock    49.308087
# Undecided           3.370271
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote_ossoff_perdue
# David Perdue    47.331515
# Jon Ossoff      48.901114
# Undecided        5.958420
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by loc_county
# Another county in Georgia    54.265549
# Cobb County, GA               9.135069
# DeKalb County, GA             9.375252
# Fulton County, GA             8.131101
# Gwinnett County, GA           7.630637
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by gender
# Female    45.513171
# Male      42.707948
# Other      0.316490
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by race
# Black, non-Hispanic    33.461877
# Hispanic                7.598438
# Other                   4.436543
# White, not Hispanic    43.040751
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by education
# Completed graduate school      9.710185
# Graduated from college        12.760498
# Graduated from high school    31.812638
# Less than high school         14.396671
# Some college, no degree       19.857617
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by income
# Between $100,000 and $150,000     9.135550
# Between $15,000 and $49,999      38.673396
# Between $50,000 and $74,999      12.278309
# Between $75,000 and $99,999       5.115371
# Over $150,000                     5.527563
# Under $15,000                    17.807419
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by age
# 18-34          27.663471
# 35-54          22.186758
# 55-64          13.430509
# 65 or older    25.256871
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote2016
# Did not vote        9.826630
# Donald Trump       25.855921
# Hillary Clinton    49.000921
# Other               3.854137
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote2020
# Did not vote     1.545581
# Donald Trump    28.522699
# Joe Biden       58.139835
# Other            0.329493
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote_warnock_loeffler
# Kelly Loeffler     27.617653
# Raphael Warnock    58.089798
# Undecided           2.830159
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote_ossoff_perdue
# David Perdue    28.153690
# Jon Ossoff      56.770015
# Undecided        3.613905
# dtype: float64
# -

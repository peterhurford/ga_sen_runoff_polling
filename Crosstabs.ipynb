# %%
import pandas as pd

from mlgear.utils import display_columns
from surveyweights import normalize_weights

# %%
survey = pd.read_csv('responses_processed_with_default_weights.csv')

# %% [markdown]
# ## Raw Demographics

# %%
demographics = ['loc_county', 'gender', 'race', 'education', 'income', 'age', 'vote2016', 'vote2020']
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    72.455516
# Fulton County, GA            10.320285
# Cobb County, GA               8.327402
# Gwinnett County, GA           6.548043
# DeKalb County, GA             2.348754
# Name: loc_county, dtype: float64
# -
# -
# ## gender ##
# Female               53.950178
# Male                 44.768683
# Other                 1.209964
# Prefer not to say     0.071174
# Name: gender, dtype: float64
# -
# -
# ## race ##
# White, not Hispanic    68.113879
# Black, non-Hispanic    21.637011
# Other                   8.469751
# Hispanic                1.779359
# Name: race, dtype: float64
# -
# -
# ## education ##
# Graduated from college        30.960854
# Some college, no degree       30.249110
# Completed graduate school     17.722420
# Graduated from high school    17.295374
# Less than high school          3.772242
# Name: education, dtype: float64
# -
# -
# ## income ##
# Between $15,000 and $49,999      36.725979
# Between $50,000 and $74,999      19.928826
# Under $15,000                    16.441281
# Between $75,000 and $99,999      11.886121
# Between $100,000 and $150,000     8.683274
# Over $150,000                     6.334520
# Name: income, dtype: float64
# -
# -
# ## age ##
# 65 or older    38.576512
# 55-64          22.989324
# 18-34          19.359431
# 35-54          19.074733
# Name: age, dtype: float64
# -
# -
# ## vote2016 ##
# Hillary Clinton    41.637011
# Donald Trump       40.996441
# Did not vote       12.740214
# Other               4.626335
# Name: vote2016, dtype: float64
# -
# -
# ## vote2020 ##
# Joe Biden       55.587189
# Donald Trump    40.498221
# Other            2.206406
# Did not vote     1.708185
# Name: vote2020, dtype: float64
# -
# -

# %% [markdown]
# ## Demographics after weighting

# %%
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * survey.groupby(var)['weight'].mean() * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    66.856037
# Cobb County, GA               7.199936
# DeKalb County, GA             7.144560
# Fulton County, GA             9.996708
# Gwinnett County, GA           8.802759
# dtype: float64
# -
# -
# ## gender ##
# Female               51.060622
# Male                 48.268777
# Other                 0.599480
# Prefer not to say     0.071121
# dtype: float64
# -
# -
# ## race ##
# Black, non-Hispanic    32.595866
# Hispanic                9.897053
# Other                   5.497792
# White, not Hispanic    52.009290
# dtype: float64
# -
# -
# ## education ##
# Completed graduate school      9.102887
# Graduated from college        18.304673
# Graduated from high school    30.094212
# Less than high school         14.096090
# Some college, no degree       28.402138
# dtype: float64
# -
# -
# ## income ##
# Between $100,000 and $150,000    12.068808
# Between $15,000 and $49,999      35.246324
# Between $50,000 and $74,999      18.006331
# Between $75,000 and $99,999      11.599689
# Over $150,000                     9.315889
# Under $15,000                    13.762958
# dtype: float64
# -
# -
# ## age ##
# 18-34          27.788201
# 35-54          35.906403
# 55-64          16.704489
# 65 or older    19.600906
# dtype: float64
# -
# -
# ## vote2016 ##
# Did not vote       12.734964
# Donald Trump       44.005986
# Hillary Clinton    39.506817
# Other               3.752234
# dtype: float64
# -
# -
# ## vote2020 ##
# Did not vote     1.708185
# Donald Trump    48.457865
# Joe Biden       48.654448
# Other            1.179502
# dtype: float64
# -
# -

# %% [markdown]
# ## Expected Vote Demographics (Demographics after Weighting + Likely Voter Model)

# %%
for var in demographics:
    print('## {} ##'.format(var))
    print(survey[var].value_counts(normalize=True) * survey.groupby(var)['lv_weight'].mean() * 100)
    print('-')
    print('-')
# Out:
# ## loc_county ##
# Another county in Georgia    69.893732
# Cobb County, GA               6.830933
# DeKalb County, GA             5.205877
# Fulton County, GA             9.341776
# Gwinnett County, GA           8.727682
# dtype: float64
# -
# -
# ## gender ##
# Female               50.082035
# Male                 49.305544
# Other                 0.552167
# Prefer not to say     0.060254
# dtype: float64
# -
# -
# ## race ##
# Black, non-Hispanic    32.572761
# Hispanic                9.147083
# Other                   5.312267
# White, not Hispanic    52.967888
# dtype: float64
# -
# -
# ## education ##
# Completed graduate school      8.956373
# Graduated from college        17.569730
# Graduated from high school    30.169418
# Less than high school         15.581855
# Some college, no degree       27.722624
# dtype: float64
# -
# -
# ## income ##
# Between $100,000 and $150,000    12.359966
# Between $15,000 and $49,999      34.366229
# Between $50,000 and $74,999      17.516048
# Between $75,000 and $99,999      12.149610
# Over $150,000                     9.819376
# Under $15,000                    13.788771
# dtype: float64
# -
# -
# ## age ##
# 18-34          23.855268
# 35-54          36.470235
# 55-64          18.130589
# 65 or older    21.543907
# dtype: float64
# -
# -
# ## vote2016 ##
# Did not vote       10.199851
# Donald Trump       47.323214
# Hillary Clinton    38.706985
# Other               3.769950
# dtype: float64
# -
# -
# ## vote2020 ##
# Did not vote     0.886670
# Donald Trump    52.166336
# Joe Biden       45.821788
# Other            1.125207
# dtype: float64
# -
# -

# %% [markdown]
# ## Demographic by Vote

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('-')
        print('---- vote choice for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print('------ "{}" 2016 vote'.format(option))
        print(survey_['vote2016'].value_counts(normalize=True) * survey_.groupby('vote2016')['lv_weight'].mean() * 100)
        print('------ "{}" 2020 vote'.format(option))
        print(survey_['vote2020'].value_counts(normalize=True) * survey_.groupby('vote2020')['lv_weight'].mean() * 100)
        print('------ "{}" Ossoff-Perdue vote'.format(option))
        print(survey_['vote_ossoff_perdue'].value_counts(normalize=True) * survey_.groupby('vote_ossoff_perdue')['lv_weight'].mean() * 100)
        print('------ "{}" Warnock-Loeffler vote'.format(option))
        print(survey_['vote_warnock_loeffler'].value_counts(normalize=True) * survey_.groupby('vote_warnock_loeffler')['lv_weight'].mean() * 100)
    print('-')
    print('-')
    print('-')
    print('-')
# Out:
# ## loc_county ##
# -
# ---- vote choice for "Another county in Georgia"
# ------ "Another county in Georgia" 2016 vote
# Did not vote        7.544310
# Donald Trump       56.708254
# Hillary Clinton    32.278083
# Other               3.469352
# dtype: float64
# ------ "Another county in Georgia" 2020 vote
# Did not vote     1.015949
# Donald Trump    59.899854
# Joe Biden       37.602152
# Other            1.482045
# dtype: float64
# ------ "Another county in Georgia" Ossoff-Perdue vote
# David Perdue    56.262463
# Jon Ossoff      37.718859
# Undecided        6.018678
# dtype: float64
# ------ "Another county in Georgia" Warnock-Loeffler vote
# Kelly Loeffler     57.772963
# Raphael Warnock    38.354989
# Undecided           3.872048
# dtype: float64
# -
# ---- vote choice for "Cobb County, GA"
# ------ "Cobb County, GA" 2016 vote
# Did not vote        8.800234
# Donald Trump       40.636977
# Hillary Clinton    40.294460
# Other              10.268329
# dtype: float64
# ------ "Cobb County, GA" 2020 vote
# Did not vote     1.167102
# Donald Trump    51.419348
# Joe Biden       47.227438
# Other            0.186112
# dtype: float64
# ------ "Cobb County, GA" Ossoff-Perdue vote
# David Perdue    53.004106
# Jon Ossoff      46.675939
# Undecided        0.319955
# dtype: float64
# ------ "Cobb County, GA" Warnock-Loeffler vote
# Kelly Loeffler     51.218734
# Raphael Warnock    47.322573
# Undecided           1.458692
# dtype: float64
# -
# ---- vote choice for "DeKalb County, GA"
# ------ "DeKalb County, GA" 2016 vote
# Did not vote       14.246872
# Donald Trump       10.124724
# Hillary Clinton    74.152378
# Other               1.476026
# dtype: float64
# ------ "DeKalb County, GA" 2020 vote
# Did not vote     1.476026
# Donald Trump     9.616228
# Joe Biden       88.390103
# Other            0.517643
# dtype: float64
# ------ "DeKalb County, GA" Ossoff-Perdue vote
# David Perdue    11.188086
# Jon Ossoff      86.308982
# Undecided        2.502932
# dtype: float64
# ------ "DeKalb County, GA" Warnock-Loeffler vote
# Kelly Loeffler     10.133871
# Raphael Warnock    87.335888
# Undecided           2.530241
# dtype: float64
# -
# ---- vote choice for "Fulton County, GA"
# ------ "Fulton County, GA" 2016 vote
# Did not vote       30.283185
# Donald Trump       20.261688
# Hillary Clinton    46.577148
# Other               2.877979
# dtype: float64
# ------ "Fulton County, GA" 2020 vote
# Did not vote     0.117557
# Donald Trump    27.630552
# Joe Biden       71.962577
# Other            0.289314
# dtype: float64
# ------ "Fulton County, GA" Ossoff-Perdue vote
# David Perdue    26.043116
# Jon Ossoff      70.584917
# Undecided        3.371967
# dtype: float64
# ------ "Fulton County, GA" Warnock-Loeffler vote
# Kelly Loeffler     26.240121
# Raphael Warnock    71.728782
# Undecided           2.031098
# dtype: float64
# -
# ---- vote choice for "Gwinnett County, GA"
# ------ "Gwinnett County, GA" 2016 vote
# Did not vote        8.651222
# Donald Trump       28.552045
# Hillary Clinton    59.382623
# Other               3.414110
# dtype: float64
# ------ "Gwinnett County, GA" 2020 vote
# Did not vote     0.103570
# Donald Trump    42.461188
# Joe Biden       57.175580
# Other            0.259661
# dtype: float64
# ------ "Gwinnett County, GA" Ossoff-Perdue vote
# David Perdue    40.696316
# Jon Ossoff      56.418465
# Undecided        2.885219
# dtype: float64
# ------ "Gwinnett County, GA" Warnock-Loeffler vote
# Kelly Loeffler     39.933808
# Raphael Warnock    56.289264
# Undecided           3.776928
# dtype: float64
# -
# -
# -
# -
# ## gender ##
# -
# ---- vote choice for "Female"
# ------ "Female" 2016 vote
# Did not vote       12.094487
# Donald Trump       43.679207
# Hillary Clinton    40.049245
# Other               4.177061
# dtype: float64
# ------ "Female" 2020 vote
# Did not vote     0.841177
# Donald Trump    48.193171
# Joe Biden       49.435556
# Other            1.530096
# dtype: float64
# ------ "Female" Ossoff-Perdue vote
# David Perdue    45.964221
# Jon Ossoff      49.000316
# Undecided        5.035463
# dtype: float64
# ------ "Female" Warnock-Loeffler vote
# Kelly Loeffler     45.389687
# Raphael Warnock    49.557989
# Undecided           5.052324
# dtype: float64
# -
# ---- vote choice for "Male"
# ------ "Male" 2016 vote
# Did not vote        7.782776
# Donald Trump       51.427345
# Hillary Clinton    37.488217
# Other               3.301662
# dtype: float64
# ------ "Male" 2020 vote
# Did not vote     0.377432
# Donald Trump    56.666812
# Joe Biden       42.229685
# Other            0.726071
# dtype: float64
# ------ "Male" Ossoff-Perdue vote
# David Perdue    52.981043
# Jon Ossoff      42.145517
# Undecided        4.873440
# dtype: float64
# ------ "Male" Warnock-Loeffler vote
# Kelly Loeffler     55.263525
# Raphael Warnock    42.858706
# Undecided           1.877770
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       55.299606
# Donald Trump       16.525057
# Hillary Clinton    19.103816
# Other               9.071521
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote    50.581787
# Donald Trump    16.360191
# Joe Biden       32.893156
# Other            0.164866
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    66.895434
# Jon Ossoff      32.939700
# Undecided        0.164866
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     65.647356
# Raphael Warnock    34.187777
# Undecided           0.164866
# dtype: float64
# -
# ---- vote choice for "Prefer not to say"
# ------ "Prefer not to say" 2016 vote
# Hillary Clinton    100.0
# dtype: float64
# ------ "Prefer not to say" 2020 vote
# Joe Biden    100.0
# dtype: float64
# ------ "Prefer not to say" Ossoff-Perdue vote
# Jon Ossoff    100.0
# dtype: float64
# ------ "Prefer not to say" Warnock-Loeffler vote
# Raphael Warnock    100.0
# dtype: float64
# -
# -
# -
# -
# ## race ##
# -
# ---- vote choice for "White, not Hispanic"
# ------ "White, not Hispanic" 2016 vote
# Did not vote        7.429205
# Donald Trump       70.392868
# Hillary Clinton    18.870869
# Other               3.307057
# dtype: float64
# ------ "White, not Hispanic" 2020 vote
# Did not vote     0.587458
# Donald Trump    75.573260
# Joe Biden       23.565809
# Other            0.273472
# dtype: float64
# ------ "White, not Hispanic" Ossoff-Perdue vote
# David Perdue    73.430277
# Jon Ossoff      23.373358
# Undecided        3.196366
# dtype: float64
# ------ "White, not Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     73.777292
# Raphael Warnock    23.273847
# Undecided           2.948860
# dtype: float64
# -
# ---- vote choice for "Black, non-Hispanic"
# ------ "Black, non-Hispanic" 2016 vote
# Did not vote       12.253731
# Donald Trump        9.502957
# Hillary Clinton    73.986166
# Other               4.257146
# dtype: float64
# ------ "Black, non-Hispanic" 2020 vote
# Did not vote     0.566036
# Donald Trump    16.571534
# Joe Biden       81.763729
# Other            1.098701
# dtype: float64
# ------ "Black, non-Hispanic" Ossoff-Perdue vote
# David Perdue    11.325830
# Jon Ossoff      81.886490
# Undecided        6.787679
# dtype: float64
# ------ "Black, non-Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     13.483806
# Raphael Warnock    83.875510
# Undecided           2.640684
# dtype: float64
# -
# ---- vote choice for "Hispanic"
# ------ "Hispanic" 2016 vote
# Did not vote       13.790376
# Donald Trump       56.496637
# Hillary Clinton    29.712987
# dtype: float64
# ------ "Hispanic" 2020 vote
# Did not vote     3.013696
# Donald Trump    54.739260
# Joe Biden       40.025842
# Other            2.221202
# dtype: float64
# ------ "Hispanic" Ossoff-Perdue vote
# David Perdue    57.752956
# Jon Ossoff      36.936774
# Undecided        5.310270
# dtype: float64
# ------ "Hispanic" Warnock-Loeffler vote
# Kelly Loeffler     58.838193
# Raphael Warnock    36.936774
# Undecided           4.225033
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       19.049539
# Donald Trump       33.402466
# Hillary Clinton    35.658512
# Other              11.889483
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote     2.173589
# Donald Trump    32.602351
# Joe Biden       57.330971
# Other            7.893089
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    30.974903
# Jon Ossoff      58.936529
# Undecided       10.088568
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     28.052865
# Raphael Warnock    59.739517
# Undecided          12.207618
# dtype: float64
# -
# -
# -
# -
# ## education ##
# -
# ---- vote choice for "Completed graduate school"
# ------ "Completed graduate school" 2016 vote
# Did not vote        2.169822
# Donald Trump       33.825665
# Hillary Clinton    57.365534
# Other               6.638980
# dtype: float64
# ------ "Completed graduate school" 2020 vote
# Did not vote     0.122615
# Donald Trump    41.431709
# Joe Biden       58.108818
# Other            0.336858
# dtype: float64
# ------ "Completed graduate school" Ossoff-Perdue vote
# David Perdue    43.120348
# Jon Ossoff      56.690208
# Undecided        0.189444
# dtype: float64
# ------ "Completed graduate school" Warnock-Loeffler vote
# Kelly Loeffler     41.782423
# Raphael Warnock    56.901136
# Undecided           1.316440
# dtype: float64
# -
# ---- vote choice for "Graduated from high school"
# ------ "Graduated from high school" 2016 vote
# Did not vote        6.333271
# Donald Trump       59.429286
# Hillary Clinton    30.898199
# Other               3.339243
# dtype: float64
# ------ "Graduated from high school" 2020 vote
# Did not vote     1.663206
# Donald Trump    59.498931
# Joe Biden       38.578446
# Other            0.259418
# dtype: float64
# ------ "Graduated from high school" Ossoff-Perdue vote
# David Perdue    56.737118
# Jon Ossoff      38.099766
# Undecided        5.163115
# dtype: float64
# ------ "Graduated from high school" Warnock-Loeffler vote
# Kelly Loeffler     55.352437
# Raphael Warnock    41.959240
# Undecided           2.688322
# dtype: float64
# -
# ---- vote choice for "Graduated from college"
# ------ "Graduated from college" 2016 vote
# Did not vote       11.520739
# Donald Trump       32.832544
# Hillary Clinton    50.075802
# Other               5.570915
# dtype: float64
# ------ "Graduated from college" 2020 vote
# <ipython-input-102-4d9642e6df09>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# Did not vote     1.052340
# Donald Trump    46.854316
# Joe Biden       51.462516
# Other            0.630828
# dtype: float64
# ------ "Graduated from college" Ossoff-Perdue vote
# David Perdue    44.804533
# Jon Ossoff      52.357044
# Undecided        2.838423
# dtype: float64
# ------ "Graduated from college" Warnock-Loeffler vote
# Kelly Loeffler     45.285964
# Raphael Warnock    52.499758
# Undecided           2.214278
# dtype: float64
# -
# ---- vote choice for "Some college, no degree"
# ------ "Some college, no degree" 2016 vote
# Did not vote       13.951526
# Donald Trump       47.643812
# Hillary Clinton    36.514753
# Other               1.889909
# dtype: float64
# ------ "Some college, no degree" 2020 vote
# Did not vote     0.681807
# Donald Trump    52.541927
# Joe Biden       45.740231
# Other            1.036035
# dtype: float64
# ------ "Some college, no degree" Ossoff-Perdue vote
# David Perdue    48.815528
# Jon Ossoff      47.093053
# Undecided        4.091418
# dtype: float64
# ------ "Some college, no degree" Warnock-Loeffler vote
# Kelly Loeffler     48.578054
# Raphael Warnock    47.101878
# Undecided           4.320067
# dtype: float64
# -
# ---- vote choice for "Less than high school"
# ------ "Less than high school" 2016 vote
# Did not vote       14.137669
# Donald Trump       47.410832
# Hillary Clinton    34.182556
# Other               4.268943
# dtype: float64
# ------ "Less than high school" 2020 vote
# Donald Trump    49.460727
# Joe Biden       46.568494
# Other            3.970779
# dtype: float64
# ------ "Less than high school" Ossoff-Perdue vote
# David Perdue    45.742465
# Jon Ossoff      43.231584
# Undecided       11.025951
# dtype: float64
# ------ "Less than high school" Warnock-Loeffler vote
# Kelly Loeffler     54.403743
# Raphael Warnock    39.554446
# Undecided           6.041811
# dtype: float64
# -
# -
# -
# -
# ## income ##
# -
# ---- vote choice for "Between $100,000 and $150,000"
# ------ "Between $100,000 and $150,000" 2016 vote
# Did not vote        7.118124
# Donald Trump       42.071960
# Hillary Clinton    47.664019
# Other               3.145897
# dtype: float64
# ------ "Between $100,000 and $150,000" 2020 vote
# Donald Trump    52.551107
# Joe Biden       46.953886
# Other            0.495006
# dtype: float64
# ------ "Between $100,000 and $150,000" Ossoff-Perdue vote
# David Perdue    52.086035
# Jon Ossoff      47.728895
# Undecided        0.185070
# dtype: float64
# ------ "Between $100,000 and $150,000" Warnock-Loeffler vote
# Kelly Loeffler     53.421466
# Raphael Warnock    46.143605
# Undecided           0.434928
# dtype: float64
# -
# ---- vote choice for "Between $50,000 and $74,999"
# ------ "Between $50,000 and $74,999" 2016 vote
# Did not vote        7.369424
# Donald Trump       51.227834
# Hillary Clinton    37.826746
# Other               3.575995
# dtype: float64
# ------ "Between $50,000 and $74,999" 2020 vote
# Did not vote     0.389224
# Donald Trump    50.955129
# Joe Biden       44.908425
# Other            3.747222
# dtype: float64
# ------ "Between $50,000 and $74,999" Ossoff-Perdue vote
# David Perdue    51.786329
# Jon Ossoff      44.336252
# Undecided        3.877419
# dtype: float64
# ------ "Between $50,000 and $74,999" Warnock-Loeffler vote
# Kelly Loeffler     51.650273
# Raphael Warnock    44.006658
# Undecided           4.343068
# dtype: float64
# -
# ---- vote choice for "Between $15,000 and $49,999"
# ------ "Between $15,000 and $49,999" 2016 vote
# Did not vote       13.267498
# Donald Trump       48.761366
# Hillary Clinton    34.846207
# Other               3.124929
# dtype: float64
# ------ "Between $15,000 and $49,999" 2020 vote
# Did not vote     1.759836
# Donald Trump    52.124576
# Joe Biden       45.992068
# Other            0.123520
# dtype: float64
# ------ "Between $15,000 and $49,999" Ossoff-Perdue vote
# David Perdue    47.900394
# Jon Ossoff      45.001247
# Undecided        7.098359
# dtype: float64
# ------ "Between $15,000 and $49,999" Warnock-Loeffler vote
# Kelly Loeffler     47.043720
# Raphael Warnock    47.783165
# Undecided           5.173115
# dtype: float64
# -
# ---- vote choice for "Under $15,000"
# ------ "Under $15,000" 2016 vote
# Did not vote       15.581107
# Donald Trump       36.673150
# Hillary Clinton    42.934818
# Other               4.810925
# dtype: float64
# ------ "Under $15,000" 2020 vote
# Did not vote     1.006519
# Donald Trump    36.564242
# Joe Biden       59.979261
# Other            2.449977
# dtype: float64
# ------ "Under $15,000" Ossoff-Perdue vote
# David Perdue    34.619461
# Jon Ossoff      54.492483
# Undecided       10.888056
# dtype: float64
# ------ "Under $15,000" Warnock-Loeffler vote
# Kelly Loeffler     41.956459
# Raphael Warnock    53.748297
# Undecided           4.295244
# dtype: float64
# -
# ---- vote choice for "Between $75,000 and $99,999"
# ------ "Between $75,000 and $99,999" 2016 vote
# Did not vote        2.024343
# Donald Trump       54.282638
# Hillary Clinton    40.739162
# Other               2.953857
# dtype: float64
# ------ "Between $75,000 and $99,999" 2020 vote
# Did not vote     0.488491
# Donald Trump    64.920597
# Joe Biden       34.365487
# Other            0.225424
# dtype: float64
# ------ "Between $75,000 and $99,999" Ossoff-Perdue vote
# David Perdue    55.315795
# Jon Ossoff      42.580796
# Undecided        2.103410
# dtype: float64
# ------ "Between $75,000 and $99,999" Warnock-Loeffler vote
# Kelly Loeffler     55.719584
# Raphael Warnock    42.177006
# Undecided           2.103410
# dtype: float64
# -
# ---- vote choice for "Over $150,000"
# ------ "Over $150,000" 2016 vote
# Did not vote       10.950695
# Donald Trump       48.278969
# Hillary Clinton    34.063443
# Other               6.706893
# dtype: float64
# ------ "Over $150,000" 2020 vote
# Did not vote     0.158537
# Donald Trump    60.116871
# Joe Biden       39.724592
# dtype: float64
# ------ "Over $150,000" Ossoff-Perdue vote
# David Perdue    61.584745
# Jon Ossoff      38.137435
# Undecided        0.277820
# dtype: float64
# ------ "Over $150,000" Warnock-Loeffler vote
# Kelly Loeffler     60.802609
# Raphael Warnock    39.024791
# Undecided           0.172601
# dtype: float64
# -
# -
# -
# -
# ## age ##
# -
# ---- vote choice for "18-34"
# ------ "18-34" 2016 vote
# Did not vote       26.334681
# Donald Trump       32.607911
# Hillary Clinton    37.283318
# Other               3.774090
# dtype: float64
# ------ "18-34" 2020 vote
# Did not vote     1.538170
# Donald Trump    36.224309
# Joe Biden       60.722193
# Other            1.515329
# dtype: float64
# ------ "18-34" Ossoff-Perdue vote
# David Perdue    33.404726
# Jon Ossoff      58.626701
# Undecided        7.968573
# dtype: float64
# ------ "18-34" Warnock-Loeffler vote
# Kelly Loeffler     37.379304
# Raphael Warnock    59.356446
# Undecided           3.264250
# dtype: float64
# -
# ---- vote choice for "35-54"
# ------ "35-54" 2016 vote
# Did not vote        6.386252
# Donald Trump       51.785757
# Hillary Clinton    37.179511
# Other               4.648480
# dtype: float64
# ------ "35-54" 2020 vote
# Did not vote     1.096732
# Donald Trump    59.188145
# Joe Biden       37.730181
# Other            1.984941
# dtype: float64
# ------ "35-54" Ossoff-Perdue vote
# David Perdue    55.864499
# Jon Ossoff      40.053716
# Undecided        4.081785
# dtype: float64
# ------ "35-54" Warnock-Loeffler vote
# Kelly Loeffler     55.030792
# Raphael Warnock    40.794519
# Undecided           4.174689
# dtype: float64
# -
# ---- vote choice for "55-64"
# ------ "55-64" 2016 vote
# Did not vote        4.583415
# Donald Trump       47.880876
# Hillary Clinton    43.323239
# Other               4.212470
# dtype: float64
# ------ "55-64" 2020 vote
# Did not vote     0.240131
# Donald Trump    53.393044
# Joe Biden       46.222381
# Other            0.144444
# dtype: float64
# ------ "55-64" Ossoff-Perdue vote
# David Perdue    51.038384
# Jon Ossoff      43.249986
# Undecided        5.711630
# dtype: float64
# ------ "55-64" Warnock-Loeffler vote
# Kelly Loeffler     49.936777
# Raphael Warnock    45.791183
# Undecided           4.272040
# dtype: float64
# -
# ---- vote choice for "65 or older"
# ------ "65 or older" 2016 vote
# Did not vote        3.516359
# Donald Trump       55.593615
# Hillary Clinton    38.984275
# Other               1.905751
# dtype: float64
# ------ "65 or older" 2020 vote
# Did not vote     0.353775
# Donald Trump    56.899616
# Joe Biden       42.683389
# Other            0.063220
# dtype: float64
# ------ "65 or older" Ossoff-Perdue vote
# David Perdue    55.308083
# Jon Ossoff      42.368590
# Undecided        2.323327
# dtype: float64
# ------ "65 or older" Warnock-Loeffler vote
# Kelly Loeffler     57.101613
# Raphael Warnock    41.128508
# Undecided           1.769879
# dtype: float64
# -
# -
# -
# -
# ## vote2016 ##
# -
# ---- vote choice for "Hillary Clinton"
# ------ "Hillary Clinton" 2016 vote
# Hillary Clinton    100.0
# dtype: float64
# ------ "Hillary Clinton" 2020 vote
# Donald Trump     7.050567
# Joe Biden       92.869598
# Other            0.079835
# dtype: float64
# ------ "Hillary Clinton" Ossoff-Perdue vote
# David Perdue     6.034574
# Jon Ossoff      91.084545
# Undecided        2.880881
# dtype: float64
# ------ "Hillary Clinton" Warnock-Loeffler vote
# Kelly Loeffler      8.014685
# Raphael Warnock    90.718727
# Undecided           1.266589
# dtype: float64
# -
# ---- vote choice for "Did not vote"
# ------ "Did not vote" 2016 vote
# Did not vote    100.0
# dtype: float64
# ------ "Did not vote" 2020 vote
# Did not vote     6.611207
# Donald Trump    19.557304
# Joe Biden       70.283989
# Other            3.547500
# dtype: float64
# ------ "Did not vote" Ossoff-Perdue vote
# David Perdue    26.090555
# Jon Ossoff      66.510318
# Undecided        7.399127
# dtype: float64
# ------ "Did not vote" Warnock-Loeffler vote
# Kelly Loeffler     22.947261
# Raphael Warnock    68.815590
# Undecided           8.237148
# dtype: float64
# -
# ---- vote choice for "Donald Trump"
# ------ "Donald Trump" 2016 vote
# Donald Trump    100.0
# dtype: float64
# ------ "Donald Trump" 2020 vote
# Did not vote     0.135415
# Donald Trump    96.647801
# Joe Biden        3.173963
# Other            0.042822
# dtype: float64
# ------ "Donald Trump" Ossoff-Perdue vote
# David Perdue    91.133935
# Jon Ossoff       4.974693
# Undecided        3.891373
# dtype: float64
# ------ "Donald Trump" Warnock-Loeffler vote
# Kelly Loeffler     92.067464
# Raphael Warnock     6.018063
# Undecided           1.914473
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Other    100.0
# dtype: float64
# ------ "Other" 2020 vote
# Did not vote     3.932513
# Donald Trump    45.242320
# Joe Biden       31.933649
# Other           18.891518
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue    36.798291
# Jon Ossoff      30.991104
# Undecided       32.210605
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler     35.290423
# Raphael Warnock    32.331534
# Undecided          32.378044
# dtype: float64
# -
# -
# -
# -
# ## vote2020 ##
# -
# ---- vote choice for "Joe Biden"
# ------ "Joe Biden" 2016 vote
# Did not vote       15.645095
# Donald Trump        3.277963
# Hillary Clinton    78.449627
# Other               2.627315
# dtype: float64
# ------ "Joe Biden" 2020 vote
# Joe Biden    100.0
# dtype: float64
# ------ "Joe Biden" Ossoff-Perdue vote
# David Perdue     1.923908
# Jon Ossoff      94.840694
# Undecided        3.235398
# dtype: float64
# ------ "Joe Biden" Warnock-Loeffler vote
# Kelly Loeffler      3.209428
# Raphael Warnock    94.993790
# Undecided           1.796782
# dtype: float64
# -
# ---- vote choice for "Donald Trump"
# ------ "Donald Trump" 2016 vote
# Did not vote        3.823953
# Donald Trump       87.675020
# Hillary Clinton     5.231462
# Other               3.269566
# dtype: float64
# ------ "Donald Trump" 2020 vote
# Donald Trump    100.0
# dtype: float64
# ------ "Donald Trump" Ossoff-Perdue vote
# David Perdue    92.077933
# Jon Ossoff       3.490931
# Undecided        4.431136
# dtype: float64
# ------ "Donald Trump" Warnock-Loeffler vote
# Kelly Loeffler     92.593523
# Raphael Warnock     4.484299
# Undecided           2.922178
# dtype: float64
# -
# ---- vote choice for "Did not vote"
# ------ "Did not vote" 2016 vote
# Did not vote    76.052371
# Donald Trump     7.227336
# Other           16.720293
# dtype: float64
# ------ "Did not vote" 2020 vote
# Did not vote    100.0
# dtype: float64
# ------ "Did not vote" Ossoff-Perdue vote
# David Perdue    57.857522
# Jon Ossoff      17.129621
# Undecided       25.012857
# dtype: float64
# ------ "Did not vote" Warnock-Loeffler vote
# Kelly Loeffler     58.266966
# Raphael Warnock    22.709127
# Undecided          19.023907
# dtype: float64
# -
# ---- vote choice for "Other"
# ------ "Other" 2016 vote
# Did not vote       32.157615
# Donald Trump        1.800967
# Hillary Clinton     2.746326
# Other              63.295091
# dtype: float64
# ------ "Other" 2020 vote
# Other    100.0
# dtype: float64
# ------ "Other" Ossoff-Perdue vote
# David Perdue     7.423072
# Jon Ossoff      11.721714
# Undecided       80.855214
# dtype: float64
# ------ "Other" Warnock-Loeffler vote
# Kelly Loeffler      4.678469
# Raphael Warnock    11.721714
# Undecided          83.599817
# dtype: float64
# -
# -
# -
# -

# %% [markdown]
# ## Vote by Demographic

# %%
for vote in ['vote_ossoff_perdue', 'vote_warnock_loeffler']:
    for choice in survey[vote].unique():
        for var in demographics:
            print('{} = {}, broken down by {}'.format(vote, choice, var))
            survey_ = survey[survey[vote] == choice]
            survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
            print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['lv_weight'].mean() * 100)
            print('-')
        print('-')
        print('-')
# Out:
# vote_ossoff_perdue = Jon Ossoff, broken down by loc_county
# Another county in Georgia    57.861352
# Cobb County, GA               6.997854
# DeKalb County, GA             9.861471
# Fulton County, GA            14.472153
# Gwinnett County, GA          10.807170
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by gender
# Female               53.860782
# Male                 45.607781
# Other                 0.399192
# Prefer not to say     0.132245
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by race
# Black, non-Hispanic    58.540798
# Hispanic                7.415380
# Other                   6.871575
# White, not Hispanic    27.172247
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by education
# Completed graduate school     11.143768
# Graduated from college        20.189799
# Graduated from high school    25.227897
# Less than high school         14.784687
# Some college, no degree       28.653850
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by income
# Between $100,000 and $150,000    12.947636
# Between $15,000 and $49,999      33.942844
# Between $50,000 and $74,999      17.044603
# Between $75,000 and $99,999      11.354498
# Over $150,000                     8.219155
# Under $15,000                    16.491264
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by age
# 18-34          30.695277
# 35-54          32.060713
# 55-64          17.210350
# 65 or older    20.033660
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by vote2016
# Did not vote       14.889313
# Donald Trump        5.166927
# Hillary Clinton    77.379486
# Other               2.564274
# dtype: float64
# -
# vote_ossoff_perdue = Jon Ossoff, broken down by vote2020
# Did not vote     0.333351
# Donald Trump     3.996901
# Joe Biden       95.380271
# Other            0.289478
# dtype: float64
# -
# -
# -
# vote_ossoff_perdue = David Perdue, broken down by loc_county
# Another county in Georgia    79.423388
# Cobb County, GA               7.312754
# DeKalb County, GA             1.176362
# Fulton County, GA             4.913758
# Gwinnett County, GA           7.173737
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by gender
# Female    46.493614
# Male      52.760353
# Other      0.746033
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by race
# Black, non-Hispanic     7.451026
# Hispanic               10.669604
# Other                   3.323390
# White, not Hispanic    78.555981
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by education
# Completed graduate school      7.800203
# Graduated from college        15.899317
# Graduated from high school    34.572090
# Less than high school         14.395613
# Some college, no degree       27.332777
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by income
# Between $100,000 and $150,000    13.002594
# Between $15,000 and $49,999      33.247761
# Between $50,000 and $74,999      18.320726
# Between $75,000 and $99,999      13.573846
# Over $150,000                    12.213735
# Under $15,000                     9.641338
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by age
# 18-34          16.094728
# 35-54          41.149627
# 55-64          18.689611
# 65 or older    24.066033
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by vote2016
# Did not vote        5.374878
# Donald Trump       87.105541
# Hillary Clinton     4.717668
# Other               2.801913
# dtype: float64
# -
# vote_ossoff_perdue = David Perdue, broken down by vote2020
# Did not vote     1.036127
# Donald Trump    97.014652
# Joe Biden        1.780524
# Other            0.168697
# dtype: float64
# -
# -
# -
# vote_ossoff_perdue = Undecided, broken down by loc_county
# Another county in Georgia    85.403551
# Cobb County, GA               0.443717
# DeKalb County, GA             2.645328
# Fulton County, GA             6.395129
# Gwinnett County, GA           5.112275
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by gender
# Female    51.198583
# Male      48.782935
# Other      0.018482
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by race
# Black, non-Hispanic    44.886162
# Hispanic                9.861337
# Other                  10.880429
# White, not Hispanic    34.372072
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by education
# Completed graduate school      0.344469
# Graduated from college        10.124620
# Graduated from high school    31.623893
# Less than high school         34.879625
# Some college, no degree       23.027393
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by income
# Between $100,000 and $150,000     0.464397
# Between $15,000 and $49,999      49.525218
# Between $50,000 and $74,999      13.788448
# Between $75,000 and $99,999       5.188273
# Over $150,000                     0.553839
# Under $15,000                    30.479826
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by age
# 18-34          38.592369
# 35-54          30.222142
# 55-64          21.023670
# 65 or older    10.161818
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by vote2016
# Did not vote       15.321839
# Donald Trump       37.386399
# Hillary Clinton    22.638691
# Other              24.653071
# dtype: float64
# -
# vote_ossoff_perdue = Undecided, broken down by vote2020
# Did not vote     4.502583
# Donald Trump    46.929079
# Joe Biden       30.097909
# Other           18.470429
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by loc_county
# Another county in Georgia    58.024901
# Cobb County, GA               6.996852
# DeKalb County, GA             9.841039
# Fulton County, GA            14.503646
# Gwinnett County, GA          10.633563
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by gender
# Female               53.721725
# Male                 45.739258
# Other                 0.408597
# Prefer not to say     0.130420
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by race
# Black, non-Hispanic    59.134926
# Hispanic                7.313006
# Other                   6.869038
# White, not Hispanic    26.683030
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by education
# Completed graduate school     11.030811
# Graduated from college        19.965339
# Graduated from high school    27.399892
# Less than high school         13.340398
# Some college, no degree       28.263560
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by income
# Between $100,000 and $150,000    12.344773
# Between $15,000 and $49,999      35.543574
# Between $50,000 and $74,999      16.684332
# Between $75,000 and $99,999      11.091554
# Over $150,000                     8.294282
# Under $15,000                    16.041485
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by age
# 18-34          30.648308
# 35-54          32.202878
# 55-64          17.970001
# 65 or older    19.178813
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by vote2016
# Did not vote       15.192701
# Donald Trump        6.164321
# Hillary Clinton    76.004727
# Other               2.638251
# dtype: float64
# -
# vote_warnock_loeffler = Raphael Warnock, broken down by vote2020
# Did not vote     0.435829
# Donald Trump     5.063364
# Joe Biden       94.215325
# Other            0.285481
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Undecided, broken down by loc_county
# Another county in Georgia    78.283800
# Cobb County, GA               2.882283
# DeKalb County, GA             3.810207
# Fulton County, GA             5.488493
# Gwinnett County, GA           9.535216
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by gender
# Female    73.192409
# Male      26.781258
# Other      0.026333
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by race
# Black, non-Hispanic    24.880774
# Hispanic               11.179070
# Other                  18.758745
# White, not Hispanic    45.181411
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by education
# Completed graduate school      3.410564
# Graduated from college        11.253566
# Graduated from high school    23.460713
# Less than high school         27.231978
# Some college, no degree       34.643180
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by income
# Between $100,000 and $150,000     1.554991
# Between $15,000 and $49,999      51.425314
# Between $50,000 and $74,999      22.005219
# Between $75,000 and $99,999       7.392292
# Over $150,000                     0.490252
# Under $15,000                    17.131930
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by age
# 18-34          22.524783
# 35-54          44.040836
# 55-64          22.404751
# 65 or older    11.029631
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by vote2016
# Did not vote       24.303210
# Donald Trump       26.206948
# Hillary Clinton    14.181358
# Other              35.308484
# dtype: float64
# -
# vote_warnock_loeffler = Undecided, broken down by vote2020
# Did not vote     4.879265
# Donald Trump    44.095064
# Joe Biden       23.815541
# Other           27.210130
# dtype: float64
# -
# -
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by loc_county
# Another county in Georgia    80.209853
# Cobb County, GA               6.949823
# DeKalb County, GA             1.047934
# Fulton County, GA             4.869228
# Gwinnett County, GA           6.923162
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by gender
# Female    45.154808
# Male      54.125159
# Other      0.720033
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by race
# Black, non-Hispanic     8.724327
# Hispanic               10.690716
# Other                   2.960206
# White, not Hispanic    77.624750
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by education
# Completed graduate school      7.433454
# Graduated from college        15.804965
# Graduated from high school    33.171761
# Less than high school         16.838864
# Some college, no degree       26.750955
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by income
# Between $100,000 and $150,000    13.115895
# Between $15,000 and $49,999      32.114294
# Between $50,000 and $74,999      17.971056
# Between $75,000 and $99,999      13.447299
# Over $150,000                    11.859625
# Under $15,000                    11.491831
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by age
# 18-34          17.712520
# 35-54          39.866598
# 55-64          17.984455
# 65 or older    24.436427
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by vote2016
# <ipython-input-103-3b9602026824>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# Did not vote        4.649321
# Donald Trump       86.545653
# Hillary Clinton     6.162269
# Other               2.642757
# dtype: float64
# -
# vote_warnock_loeffler = Kelly Loeffler, broken down by vote2020
# Did not vote     1.026240
# Donald Trump    95.947970
# Joe Biden        2.921221
# Other            0.104569
# dtype: float64
# -
# -
# -

# %% [markdown]
# ## Demographic by Likely Voter

# %%
demographics += ['vote_warnock_loeffler', 'vote_ossoff_perdue']
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- likely voter breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['lv_likely'].value_counts(normalize=True) * survey_.groupby('lv_likely')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- likely voter breakdown for "Another county in Georgia"
# Already voted      56.603442
# Likely              1.880269
# Somewhat likely     1.251131
# Very likely        41.729996
# dtype: float64
# -
# ---- likely voter breakdown for "Cobb County, GA"
# Already voted      52.755148
# Likely              0.571689
# Somewhat likely     1.356616
# Very likely        38.127883
# dtype: float64
# -
# ---- likely voter breakdown for "DeKalb County, GA"
# Likely              0.692435
# Somewhat likely     2.480260
# Very likely        90.045648
# dtype: float64
# -
# ---- likely voter breakdown for "Fulton County, GA"
# Already voted      38.123132
# Likely              0.533236
# Somewhat likely     0.728944
# Very likely        59.080858
# dtype: float64
# -
# ---- likely voter breakdown for "Gwinnett County, GA"
# Already voted      38.347387
# Likely              2.377669
# Somewhat likely     0.632613
# Very likely        57.275604
# dtype: float64
# -
# ## gender ##
# ---- likely voter breakdown for "Female"
# Already voted      44.325500
# Likely              0.850994
# Somewhat likely     0.824367
# Very likely        49.425947
# dtype: float64
# -
# ---- likely voter breakdown for "Male"
# Already voted      54.523098
# Likely              2.262368
# Somewhat likely     1.598308
# Very likely        42.527577
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted    80.817574
# Likely            2.071706
# Very likely      17.110720
# dtype: float64
# -
# ---- likely voter breakdown for "Prefer not to say"
# Likely    100.0
# dtype: float64
# -
# ## race ##
# ---- likely voter breakdown for "White, not Hispanic"
# Already voted      47.121416
# Likely              1.925197
# Somewhat likely     1.747467
# Very likely        49.375816
# dtype: float64
# -
# ---- likely voter breakdown for "Black, non-Hispanic"
# Already voted      53.886091
# Likely              0.555617
# Somewhat likely     0.300361
# Very likely        41.655257
# dtype: float64
# -
# ---- likely voter breakdown for "Hispanic"
# Already voted    55.591158
# Likely            3.188306
# Very likely      44.409011
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      45.930490
# Likely              3.060469
# Somewhat likely     3.389301
# Very likely        48.247610
# dtype: float64
# -
# ## education ##
# ---- likely voter breakdown for "Completed graduate school"
# Already voted      63.062880
# Likely              2.629526
# Somewhat likely     1.430918
# Very likely        29.048133
# dtype: float64
# -
# ---- likely voter breakdown for "Graduated from high school"
# Already voted      48.849657
# Likely              1.082370
# Somewhat likely     0.695864
# Very likely        42.951533
# dtype: float64
# -
# ---- likely voter breakdown for "Graduated from college"
# Already voted      39.243710
# Likely              1.940600
# Somewhat likely     0.668697
# Very likely        52.152415
# dtype: float64
# -
# ---- likely voter breakdown for "Some college, no degree"
# Already voted      35.422964
# Likely              2.491585
# Somewhat likely     1.541171
# Very likely        57.876159
# dtype: float64
# -
# ---- likely voter breakdown for "Less than high school"
# Already voted      71.944048
# Somewhat likely     1.861337
# Very likely        26.194616
# dtype: float64
# -
# ## income ##
# ---- likely voter breakdown for "Between $100,000 and $150,000"
# Already voted      49.185225
# Likely              1.709509
# Somewhat likely     0.129519
# Very likely        51.603681
# dtype: float64
# -
# ---- likely voter breakdown for "Between $50,000 and $74,999"
# Already voted      47.215279
# Likely              2.190877
# Somewhat likely     1.116152
# Very likely        43.104782
# dtype: float64
# -
# ---- likely voter breakdown for "Between $15,000 and $49,999"
# Already voted      48.346835
# Likely              1.321594
# Somewhat likely     0.582652
# Very likely        45.487191
# dtype: float64
# -
# ---- likely voter breakdown for "Under $15,000"
# Already voted      62.565317
# Likely              1.769569
# Somewhat likely     3.566557
# Very likely        34.749102
# dtype: float64
# -
# ---- likely voter breakdown for "Between $75,000 and $99,999"
# Already voted      41.753288
# Likely              2.392663
# Somewhat likely     2.392733
# Very likely        53.553128
# dtype: float64
# -
# ---- likely voter breakdown for "Over $150,000"
# Already voted    48.876294
# Likely            0.332447
# Very likely      49.965883
# dtype: float64
# -
# ## age ##
# ---- likely voter breakdown for "18-34"
# Already voted      38.957744
# Likely              4.780706
# Somewhat likely     0.986399
# Very likely        60.630087
# dtype: float64
# -
# ---- likely voter breakdown for "35-54"
# Already voted      37.959471
# Likely              1.724131
# Somewhat likely     1.049872
# Very likely        64.243082
# dtype: float64
# -
# ---- likely voter breakdown for "55-64"
# Already voted      68.130230
# Likely              0.181323
# Somewhat likely     1.275150
# Very likely        32.439496
# dtype: float64
# -
# ---- likely voter breakdown for "65 or older"
# Already voted      74.423397
# Somewhat likely     1.839558
# Very likely        24.609258
# dtype: float64
# -
# ## vote2016 ##
# ---- likely voter breakdown for "Hillary Clinton"
# Already voted      57.296436
# Likely              1.632894
# Somewhat likely     0.509605
# Very likely        36.226555
# dtype: float64
# -
# ---- likely voter breakdown for "Did not vote"
# Already voted      23.570618
# Likely              6.999716
# Somewhat likely     2.426315
# Very likely        59.680573
# dtype: float64
# -
# ---- likely voter breakdown for "Donald Trump"
# Already voted      46.627057
# Likely              0.305259
# Somewhat likely     1.101765
# Very likely        51.827946
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      72.212947
# Likely              3.167400
# Somewhat likely     6.064236
# Very likely        26.308951
# dtype: float64
# -
# ## vote2020 ##
# ---- likely voter breakdown for "Joe Biden"
# Already voted      52.931758
# Likely              1.993005
# Somewhat likely     0.645764
# Very likely        38.455641
# dtype: float64
# -
# ---- likely voter breakdown for "Donald Trump"
# Already voted      45.554281
# Likely              0.686378
# Somewhat likely     1.373283
# Very likely        51.971533
# dtype: float64
# -
# ---- likely voter breakdown for "Did not vote"
# Already voted      31.176470
# Somewhat likely     9.692548
# Very likely        39.029379
# dtype: float64
# -
# ---- likely voter breakdown for "Other"
# Already voted      62.862910
# Likely             33.373266
# Somewhat likely     2.523948
# Very likely        17.374453
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- likely voter breakdown for "Raphael Warnock"
# Already voted      51.424752
# Likely              2.045295
# Somewhat likely     0.471880
# Very likely        40.102753
# dtype: float64
# -
# ---- likely voter breakdown for "Undecided"
# Already voted      44.519546
# Likely              9.143043
# Somewhat likely    11.295955
# Very likely        37.755631
# dtype: float64
# -
# ---- likely voter breakdown for "Kelly Loeffler"
# Already voted      47.083707
# Likely              0.661496
# Somewhat likely     1.098308
# Very likely        50.734391
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- likely voter breakdown for "Jon Ossoff"
# Already voted      51.338012
# Likely              2.096431
# Somewhat likely     0.762961
# Very likely        39.751939
# dtype: float64
# -
# ---- likely voter breakdown for "David Perdue"
# Already voted      45.417765
# Likely              0.783630
# Somewhat likely     1.117547
# Very likely        52.453725
# dtype: float64
# -
# ---- likely voter breakdown for "Undecided"
# Already voted      63.510496
# Likely              5.271072
# Somewhat likely     5.573289
# Very likely        27.278741
# dtype: float64
# -
# <ipython-input-104-6cf45613cb4b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])

# %% [markdown]
# ## Likely Voter by Demographic

# %%
for lvx in survey['lv_likely'].unique():
    if isinstance(lvx, str):
        for var in demographics:
            print('lv_likely = {}, broken down by {}'.format(lvx, var))
            survey_ = survey[survey['lv_likely'] == lvx]
            survey_['weight'] = normalize_weights(survey_['weight'])
            print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
            print('-')
# Out:
# lv_likely = Very likely, broken down by loc_county
# Another county in Georgia    62.845092
# Cobb County, GA               5.863271
# DeKalb County, GA             9.074698
# Fulton County, GA            11.475932
# Gwinnett County, GA          10.741007
# dtype: float64
# -
# lv_likely = Very likely, broken down by gender
# Female    54.814506
# Male      44.934192
# Other      0.251303
# dtype: float64
# -
# lv_likely = Very likely, broken down by race
# Black, non-Hispanic    29.763362
# Hispanic                8.183610
# Other                   5.515601
# White, not Hispanic    56.537428
# dtype: float64
# -
# lv_likely = Very likely, broken down by education
# Completed graduate school      5.749692
# Graduated from college        20.430786
# Graduated from high school    29.712866
# Less than high school          9.046176
# Some college, no degree       35.060480
# dtype: float64
# -
# lv_likely = Very likely, broken down by income
# Between $100,000 and $150,000    13.257005
# Between $15,000 and $49,999      34.559180
# Between $50,000 and $74,999      17.045930
# Between $75,000 and $99,999      14.307663
# Over $150,000                    10.635068
# Under $15,000                    10.195154
# dtype: float64
# -
# lv_likely = Very likely, broken down by age
# 18-34          27.618841
# 35-54          48.078693
# 55-64          12.659304
# 65 or older    11.643163
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote2016
# Did not vote       13.523072
# Donald Trump       53.645430
# Hillary Clinton    30.747860
# Other               2.083639
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote2020
# Did not vote     1.293074
# Donald Trump    59.639577
# Joe Biden       38.678650
# Other            0.388699
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     56.358846
# Raphael Warnock    40.616256
# Undecided           3.024899
# dtype: float64
# -
# lv_likely = Very likely, broken down by vote_ossoff_perdue
# David Perdue    57.201636
# Jon Ossoff      39.757765
# Undecided        3.040599
# dtype: float64
# -
# lv_likely = Likely, broken down by loc_county
# Another county in Georgia    80.017097
# Cobb County, GA               2.484257
# DeKalb County, GA             1.971915
# Fulton County, GA             2.926850
# Gwinnett County, GA          12.599881
# dtype: float64
# -
# lv_likely = Likely, broken down by gender
# Female               26.668999
# Male                 67.547501
# Other                 0.859798
# Prefer not to say     4.923701
# dtype: float64
# -
# lv_likely = Likely, broken down by race
# Black, non-Hispanic    11.218315
# Hispanic               16.602502
# Other                   9.886551
# White, not Hispanic    62.292631
# dtype: float64
# -
# lv_likely = Likely, broken down by education
# Completed graduate school     14.707660
# Graduated from college        21.482582
# Graduated from high school    21.158324
# Some college, no degree       42.651434
# dtype: float64
# -
# lv_likely = Likely, broken down by income
# Between $100,000 and $150,000    12.410118
# Between $15,000 and $49,999      28.373440
# Between $50,000 and $74,999      24.482342
# Between $75,000 and $99,999      18.063637
# Over $150,000                     1.999536
# Under $15,000                    14.670926
# dtype: float64
# -
# lv_likely = Likely, broken down by age
# 18-34    61.538810
# 35-54    36.461654
# 55-64     1.999536
# dtype: float64
# -
# lv_likely = Likely, broken down by vote2016
# Did not vote       44.819043
# Donald Trump        8.928473
# Hillary Clinton    39.163867
# Other               7.088617
# dtype: float64
# -
# lv_likely = Likely, broken down by vote2020
# Donald Trump    22.257285
# Joe Biden       56.644731
# Other           21.097984
# dtype: float64
# -
# lv_likely = Likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     20.764732
# Raphael Warnock    58.535776
# Undecided          20.699492
# dtype: float64
# -
# lv_likely = Likely, broken down by vote_ossoff_perdue
# David Perdue    24.148097
# Jon Ossoff      59.249401
# Undecided       16.602502
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by loc_county
# Another county in Georgia    72.385569
# Cobb County, GA               8.014575
# DeKalb County, GA             9.602691
# Fulton County, GA             5.439531
# Gwinnett County, GA           4.557634
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by gender
# Female    35.122652
# Male      64.877348
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by race
# Black, non-Hispanic     8.244825
# Other                  14.885156
# White, not Hispanic    76.870019
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by education
# Completed graduate school     10.880963
# Graduated from college        10.063893
# Graduated from high school    18.493397
# Less than high school         24.694721
# Some college, no degree       35.867026
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by income
# Between $100,000 and $150,000     1.278272
# Between $15,000 and $49,999      17.006295
# Between $50,000 and $74,999      16.956839
# Between $75,000 and $99,999      24.558638
# Under $15,000                    40.199955
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by age
# 18-34          17.262193
# 35-54          30.184826
# 55-64          19.117149
# 65 or older    33.435832
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote2016
# Did not vote       21.121067
# Donald Trump       43.811073
# Hillary Clinton    16.616802
# Other              18.451057
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote2020
# Did not vote    12.336609
# Donald Trump    60.541794
# Joe Biden       24.952350
# Other            2.169247
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote_warnock_loeffler
# Kelly Loeffler     46.871635
# Raphael Warnock    18.360474
# Undecided          34.767890
# dtype: float64
# -
# lv_likely = Somewhat likely, broken down by vote_ossoff_perdue
# David Perdue    46.819225
# Jon Ossoff      29.315162
# Undecided       23.865614
# dtype: float64
# -
# lv_likely = Already voted, broken down by loc_county
# Another county in Georgia    78.964014
# Cobb County, GA               7.514939
# Fulton County, GA             6.859510
# Gwinnett County, GA           6.661537
# dtype: float64
# -
# lv_likely = Already voted, broken down by gender
# Female    45.536274
# Male      53.364220
# Other      1.099507
# dtype: float64
# -
# lv_likely = Already voted, broken down by race
# Black, non-Hispanic    35.665819
# Hispanic                9.489490
# Other                   4.863864
# White, not Hispanic    49.980827
# dtype: float64
# -
# lv_likely = Already voted, broken down by education
# Completed graduate school     11.562814
# Graduated from college        14.241117
# Graduated from high school    31.303344
# Less than high school         23.015012
# Some college, no degree       19.877713
# dtype: float64
# -
# lv_likely = Already voted, broken down by income
# Between $100,000 and $150,000    11.704766
# Between $15,000 and $49,999      34.025593
# Between $50,000 and $74,999      17.295820
# Between $75,000 and $99,999      10.333273
# Over $150,000                     9.636700
# Under $15,000                    17.003847
# dtype: float64
# -
# lv_likely = Already voted, broken down by age
# 18-34          16.438962
# 35-54          26.315388
# 55-64          24.628554
# 65 or older    32.617096
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote2016
# Did not vote        4.947396
# Donald Trump       44.706440
# Hillary Clinton    45.048343
# Other               5.297821
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote2020
# Did not vote     0.956802
# Donald Trump    48.424101
# Joe Biden       49.316350
# Other            1.302748
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote_warnock_loeffler
# Kelly Loeffler     48.449983
# Raphael Warnock    48.245992
# Undecided           3.304024
# dtype: float64
# -
# lv_likely = Already voted, broken down by vote_ossoff_perdue
# David Perdue    45.879769
# Jon Ossoff      47.562650
# Undecided        6.557581
# dtype: float64
# -
# <ipython-input-113-59f3812805f3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])

# %% [markdown]
# ## Demographic by Likely Voter Score

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- likely voter score for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['lv_index'].value_counts(normalize=True) * survey_.groupby('lv_index')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- likely voter score for "Another county in Georgia"
# 0.11     0.847495
# 0.23     5.981082
# 0.40     1.029939
# 0.59     1.133701
# 0.63     1.728813
# 0.83    89.278969
# dtype: float64
# -
# ---- likely voter score for "Cobb County, GA"
# 0.23    19.789927
# 0.40     0.480318
# 0.59     1.121783
# 0.63     0.498395
# 0.83    78.109577
# dtype: float64
# -
# ---- likely voter score for "DeKalb County, GA"
# 0.23    46.328833
# 0.40     1.428029
# 0.59     1.355532
# 0.63     0.398675
# 0.83    50.488932
# dtype: float64
# -
# ---- likely voter score for "Fulton County, GA"
# 0.23    21.906141
# 0.40     0.578128
# 0.59     0.138458
# 0.63     0.422911
# 0.83    76.954362
# dtype: float64
# -
# ---- likely voter score for "Gwinnett County, GA"
# 0.11     0.694180
# 0.23    13.537757
# 0.40     0.550098
# 0.63     2.067538
# 0.83    83.150427
# dtype: float64
# <ipython-input-106-530baa19b739>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# -
# ## gender ##
# ---- likely voter score for "Female"
# 0.11     1.229340
# 0.23    14.383022
# 0.40     0.518455
# 0.59     0.727882
# 0.63     0.754443
# 0.83    82.386857
# dtype: float64
# -
# ---- likely voter score for "Male"
# 0.23     9.884437
# 0.40     1.381176
# 0.59     0.467645
# 0.63     2.021384
# 0.83    86.245359
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.59    58.720157
# 0.63     2.071706
# 0.83    39.208137
# dtype: float64
# -
# ---- likely voter score for "Prefer not to say"
# 0.63    100.0
# dtype: float64
# -
# ## race ##
# ---- likely voter score for "White, not Hispanic"
# 0.11     0.861352
# 0.23     9.262560
# 0.40     1.429601
# 0.59     0.538602
# 0.63     1.730062
# 0.83    86.177823
# dtype: float64
# -
# ---- likely voter score for "Black, non-Hispanic"
# 0.11     0.551376
# 0.23    13.375932
# 0.40     0.091197
# 0.59     0.540896
# 0.63     0.497131
# 0.83    84.943468
# dtype: float64
# -
# ---- likely voter score for "Hispanic"
# 0.23    21.576760
# 0.59     3.510537
# 0.63     2.423112
# 0.83    72.489591
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.23    14.593152
# 0.40     2.876634
# 0.59     2.647076
# 0.63     2.597541
# 0.83    77.285598
# dtype: float64
# -
# ## education ##
# ---- likely voter score for "Completed graduate school"
# 0.23    14.643004
# 0.40     1.270011
# 0.59     0.152053
# 0.63     2.333836
# 0.83    81.601096
# dtype: float64
# -
# ---- likely voter score for "Graduated from high school"
# 0.11     1.744681
# 0.23    10.644709
# 0.40     0.460604
# 0.59     1.701244
# 0.63     1.015557
# 0.83    84.433206
# dtype: float64
# -
# ---- likely voter score for "Graduated from college"
# 0.23    17.880321
# 0.40     0.584149
# 0.59     1.273082
# 0.63     1.695237
# 0.83    78.567211
# dtype: float64
# -
# ---- likely voter score for "Some college, no degree"
# 0.11     0.361453
# 0.23    15.160286
# 0.40     1.083997
# 0.59     0.670908
# 0.63     2.169145
# 0.83    80.554211
# dtype: float64
# -
# ---- likely voter score for "Less than high school"
# 0.40     1.861337
# 0.83    98.138663
# dtype: float64
# -
# ## income ##
# ---- likely voter score for "Between $100,000 and $150,000"
# 0.23    10.831468
# 0.40     0.112533
# 0.63     1.485311
# 0.83    87.570689
# dtype: float64
# -
# ---- likely voter score for "Between $50,000 and $74,999"
# 0.11     1.109395
# 0.23    14.960606
# 0.40     1.000551
# 0.59     0.270371
# 0.63     1.963964
# 0.83    80.695112
# dtype: float64
# -
# ---- likely voter score for "Between $15,000 and $49,999"
# 0.11     0.704248
# 0.23    15.204393
# 0.40     0.369166
# 0.59     1.975424
# 0.63     1.162797
# 0.83    80.583971
# dtype: float64
# -
# ---- likely voter score for "Under $15,000"
# 0.11     1.305865
# 0.23     9.959757
# 0.40     2.518441
# 0.59     0.799475
# 0.63     1.539755
# 0.83    83.876707
# dtype: float64
# -
# ---- likely voter score for "Between $75,000 and $99,999"
# 0.23     5.901710
# 0.40     2.249455
# 0.59     0.644867
# 0.63     2.249390
# 0.83    88.954578
# dtype: float64
# -
# ---- likely voter score for "Over $150,000"
# 0.23     7.511305
# 0.59     0.210614
# 0.63     0.310035
# 0.83    91.968045
# dtype: float64
# -
# ## age ##
# ---- likely voter score for "18-34"
# 0.11     1.735080
# 0.23    27.851511
# 0.40     0.578579
# 0.59     1.309040
# 0.63     3.198855
# 0.83    65.326935
# dtype: float64
# -
# ---- likely voter score for "35-54"
# 0.11     0.405390
# 0.23    10.427037
# 0.40     0.752335
# 0.59     1.273507
# 0.63     1.466798
# 0.83    85.674933
# dtype: float64
# -
# ---- likely voter score for "55-64"
# 0.23     3.058311
# 0.40     0.869480
# 0.59     0.193435
# 0.63     0.172903
# 0.83    95.705871
# dtype: float64
# -
# ---- likely voter score for "65 or older"
# 0.23     0.616676
# 0.40     1.812406
# 0.59     0.490086
# 0.83    97.080832
# dtype: float64
# -
# ## vote2016 ##
# ---- likely voter score for "Hillary Clinton"
# 0.23    16.108725
# 0.40     0.446884
# 0.63     1.431922
# 0.83    82.012469
# dtype: float64
# -
# ---- likely voter score for "Did not vote"
# 0.11     4.929017
# 0.23    28.792745
# 0.40     0.732886
# 0.59     5.353616
# 0.63     5.083593
# 0.83    55.108143
# dtype: float64
# -
# ---- likely voter score for "Donald Trump"
# 0.23     4.125518
# 0.40     1.057771
# 0.59     0.183538
# 0.63     0.293070
# 0.83    94.340103
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.23     7.166186
# 0.40     5.224573
# 0.59     4.979814
# 0.63     2.728837
# 0.83    79.900590
# dtype: float64
# -
# ## vote2020 ##
# ---- likely voter score for "Joe Biden"
# 0.23    20.661659
# 0.40     0.544889
# 0.63     1.681678
# 0.83    77.111774
# dtype: float64
# -
# ---- likely voter score for "Donald Trump"
# 0.23     3.739875
# 0.40     1.327426
# 0.63     0.663459
# 0.83    94.269241
# dtype: float64
# -
# ---- likely voter score for "Did not vote"
# 0.11    36.747102
# 0.23     7.673267
# 0.59    55.579631
# dtype: float64
# -
# ---- likely voter score for "Other"
# 0.23    10.089360
# 0.40     1.954024
# 0.63    25.837367
# 0.83    62.119249
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- likely voter score for "Raphael Warnock"
# 0.11     0.447875
# 0.23    20.978815
# 0.40     0.277702
# 0.59     0.384495
# 0.63     1.711369
# 0.83    76.199744
# dtype: float64
# -
# ---- likely voter score for "Undecided"
# 0.11     5.617535
# 0.23     5.070673
# 0.40     8.051151
# 0.59     3.955736
# 0.63     8.127150
# 0.83    69.177755
# dtype: float64
# -
# ---- likely voter score for "Kelly Loeffler"
# 0.11     0.425798
# 0.23     3.333126
# 0.40     1.061504
# 0.59     1.308564
# 0.63     0.639329
# 0.83    93.231679
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- likely voter score for "Jon Ossoff"
# 0.11     0.452746
# 0.23    21.193176
# 0.40     0.518863
# 0.59     0.261100
# 0.63     1.751073
# 0.83    75.823041
# dtype: float64
# -
# ---- likely voter score for "David Perdue"
# 0.11     0.432419
# 0.23     3.432460
# 0.40     1.076803
# 0.59     1.319004
# 0.63     0.755060
# 0.83    92.984253
# dtype: float64
# -
# ---- likely voter score for "Undecided"
# 0.11     4.193055
# 0.23     3.476472
# 0.40     3.659418
# 0.59     4.310549
# 0.63     4.865605
# 0.83    79.494901
# dtype: float64
# -

# %% [markdown]
# ## Likely Voter Score by Demographic

# %%
for lvx in sorted(survey['lv_index'].unique())[::-1]:
    for var in demographics:
        print('lv_index = {}, broken down by {}'.format(lvx, var))
        survey_ = survey[survey['lv_index'] == lvx]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# lv_index = 0.83, broken down by loc_county
# Another county in Georgia    71.115278
# Cobb County, GA               6.700482
# DeKalb County, GA             4.297786
# Fulton County, GA             9.165652
# Gwinnett County, GA           8.720802
# dtype: float64
# -
# lv_index = 0.83, broken down by gender
# Female    50.120703
# Male      49.599254
# Other      0.280042
# dtype: float64
# -
# lv_index = 0.83, broken down by race
# Black, non-Hispanic    32.988733
# Hispanic                8.547806
# Other                   5.062441
# White, not Hispanic    53.401021
# dtype: float64
# -
# lv_index = 0.83, broken down by education
# Completed graduate school      8.850101
# Graduated from college        17.134697
# Graduated from high school    30.273969
# Less than high school         16.482076
# Some college, no degree       27.259156
# dtype: float64
# -
# lv_index = 0.83, broken down by income
# Between $100,000 and $150,000    12.592045
# Between $15,000 and $49,999      33.840410
# Between $50,000 and $74,999      17.311934
# Between $75,000 and $99,999      12.293846
# Over $150,000                    10.207852
# Under $15,000                    13.753913
# dtype: float64
# -
# lv_index = 0.83, broken down by age
# 18-34          21.628472
# 35-54          36.652094
# 55-64          19.047803
# 65 or older    22.671631
# dtype: float64
# -
# lv_index = 0.83, broken down by vote2016
# Did not vote        8.361546
# Donald Trump       49.463087
# Hillary Clinton    38.603354
# Other               3.572013
# dtype: float64
# -
# lv_index = 0.83, broken down by vote2020
# Donald Trump    54.426123
# Joe Biden       44.700910
# Other            0.872967
# dtype: float64
# -
# lv_index = 0.83, broken down by vote_warnock_loeffler
# Kelly Loeffler     52.112803
# Raphael Warnock    44.854934
# Undecided           3.032263
# dtype: float64
# -
# lv_index = 0.83, broken down by vote_ossoff_perdue
# David Perdue    51.178766
# Jon Ossoff      44.152974
# Undecided        4.668260
# dtype: float64
# -
# lv_index = 0.63, broken down by loc_county
# Another county in Georgia    80.017097
# Cobb County, GA               2.484257
# DeKalb County, GA             1.971915
# Fulton County, GA             2.926850
# Gwinnett County, GA          12.599881
# dtype: float64
# -
# lv_index = 0.63, broken down by gender
# Female               26.668999
# Male                 67.547501
# Other                 0.859798
# Prefer not to say     4.923701
# dtype: float64
# -
# lv_index = 0.63, broken down by race
# Black, non-Hispanic    11.218315
# Hispanic               16.602502
# Other                   9.886551
# White, not Hispanic    62.292631
# dtype: float64
# -
# lv_index = 0.63, broken down by education
# Completed graduate school     14.707660
# Graduated from college        21.482582
# Graduated from high school    21.158324
# Some college, no degree       42.651434
# dtype: float64
# -
# lv_index = 0.63, broken down by income
# Between $100,000 and $150,000    12.410118
# Between $15,000 and $49,999      28.373440
# Between $50,000 and $74,999      24.482342
# Between $75,000 and $99,999      18.063637
# Over $150,000                     1.999536
# Under $15,000                    14.670926
# dtype: float64
# -
# lv_index = 0.63, broken down by age
# 18-34    61.538810
# 35-54    36.461654
# 55-64     1.999536
# dtype: float64
# -
# lv_index = 0.63, broken down by vote2016
# Did not vote       44.819043
# Donald Trump        8.928473
# Hillary Clinton    39.163867
# Other               7.088617
# dtype: float64
# -
# lv_index = 0.63, broken down by vote2020
# Donald Trump    22.257285
# Joe Biden       56.644731
# Other           21.097984
# dtype: float64
# -
# lv_index = 0.63, broken down by vote_warnock_loeffler
# Kelly Loeffler     20.764732
# Raphael Warnock    58.535776
# Undecided          20.699492
# dtype: float64
# -
# lv_index = 0.63, broken down by vote_ossoff_perdue
# David Perdue    24.148097
# Jon Ossoff      59.249401
# Undecided       16.602502
# dtype: float64
# -
# lv_index = 0.59, broken down by loc_county
# Another county in Georgia    79.834105
# Cobb County, GA               8.507203
# DeKalb County, GA            10.200808
# Fulton County, GA             1.457884
# dtype: float64
# -
# lv_index = 0.59, broken down by gender
# Female    39.146844
# Male      23.775607
# Other     37.077549
# dtype: float64
# -
# lv_index = 0.59, broken down by race
# Black, non-Hispanic    18.570581
# Hispanic               36.595597
# Other                  15.328655
# White, not Hispanic    29.505168
# dtype: float64
# -
# lv_index = 0.59, broken down by education
# Completed graduate school      1.457884
# Graduated from college        24.545275
# Graduated from high school    53.926087
# Some college, no degree       20.070754
# dtype: float64
# -
# lv_index = 0.59, broken down by income
# Between $15,000 and $49,999    73.337081
# Between $50,000 and $74,999     5.127847
# Between $75,000 and $99,999     7.878907
# Over $150,000                   2.066624
# Under $15,000                  11.589541
# dtype: float64
# -
# lv_index = 0.59, broken down by age
# 18-34          38.314467
# 35-54          48.164022
# 55-64           3.403431
# 65 or older    10.118079
# dtype: float64
# -
# lv_index = 0.59, broken down by vote2016
# Did not vote    71.811558
# Donald Trump     8.507203
# Other           19.681239
# dtype: float64
# -
# lv_index = 0.59, broken down by vote2020
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.59, broken down by vote_warnock_loeffler
# Kelly Loeffler     64.662436
# Raphael Warnock    20.008909
# Undecided          15.328655
# dtype: float64
# -
# lv_index = 0.59, broken down by vote_ossoff_perdue
# David Perdue    64.180484
# Jon Ossoff      13.441345
# Undecided       22.378170
# dtype: float64
# -
# lv_index = 0.4, broken down by loc_county
# Another county in Georgia    73.928961
# Cobb County, GA               3.712953
# DeKalb County, GA            10.954049
# Fulton County, GA             6.205020
# Gwinnett County, GA           5.199017
# dtype: float64
# -
# lv_index = 0.4, broken down by gender
# Female    28.42234
# Male      71.57766
# dtype: float64
# -
# lv_index = 0.4, broken down by race
# Black, non-Hispanic     3.191565
# Other                  16.979900
# White, not Hispanic    79.828535
# dtype: float64
# -
# lv_index = 0.4, broken down by education
# Completed graduate school     12.412208
# Graduated from college        11.480155
# Graduated from high school    14.882388
# Less than high school         28.169936
# Some college, no degree       33.055312
# dtype: float64
# -
# lv_index = 0.4, broken down by income
# Between $100,000 and $150,000     1.458160
# Between $15,000 and $49,999      13.970051
# Between $50,000 and $74,999      19.343125
# Between $75,000 and $99,999      28.014703
# Under $15,000                    37.213962
# dtype: float64
# -
# lv_index = 0.4, broken down by age
# 18-34          17.261765
# 35-54          29.003158
# 55-64          15.593919
# 65 or older    38.141157
# dtype: float64
# -
# lv_index = 0.4, broken down by vote2016
# Did not vote       10.020669
# Donald Trump       49.976476
# Hillary Clinton    18.955236
# Other              21.047619
# dtype: float64
# -
# lv_index = 0.4, broken down by vote2020
# Donald Trump    69.061661
# Joe Biden       28.463820
# Other            2.474519
# dtype: float64
# -
# lv_index = 0.4, broken down by vote_warnock_loeffler
# Kelly Loeffler     53.467741
# Raphael Warnock    14.730760
# Undecided          31.801498
# dtype: float64
# -
# lv_index = 0.4, broken down by vote_ossoff_perdue
# David Perdue    53.407955
# Jon Ossoff      27.227068
# Undecided       19.364977
# dtype: float64
# -
# lv_index = 0.23, broken down by loc_county
# Another county in Georgia    33.005884
# Cobb County, GA              11.760988
# DeKalb County, GA            27.321075
# Fulton County, GA            18.075647
# Gwinnett County, GA           9.836407
# dtype: float64
# -
# lv_index = 0.23, broken down by gender
# Female    60.61878
# Male      39.38122
# dtype: float64
# -
# lv_index = 0.23, broken down by race
# Black, non-Hispanic    35.987986
# Hispanic               17.626377
# Other                   6.622292
# White, not Hispanic    39.763345
# dtype: float64
# -
# lv_index = 0.23, broken down by education
# Completed graduate school     11.002219
# Graduated from college        27.015204
# Graduated from high school    26.441599
# Some college, no degree       35.540978
# dtype: float64
# -
# lv_index = 0.23, broken down by income
# Between $100,000 and $150,000    10.790030
# Between $15,000 and $49,999      44.233762
# Between $50,000 and $74,999      22.235422
# Between $75,000 and $99,999       5.650607
# Over $150,000                     5.775780
# Under $15,000                    11.314399
# dtype: float64
# -
# lv_index = 0.23, broken down by age
# <ipython-input-107-1e9494554290>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# 18-34          63.882241
# 35-54          30.903222
# 55-64           4.216827
# 65 or older     0.997710
# dtype: float64
# -
# lv_index = 0.23, broken down by vote2016
# Did not vote       30.265770
# Donald Trump       14.985155
# Hillary Clinton    52.529607
# Other               2.219468
# dtype: float64
# -
# lv_index = 0.23, broken down by vote2020
# Did not vote     1.081898
# Donald Trump    14.958645
# Joe Biden       82.977182
# Other            0.982275
# dtype: float64
# -
# lv_index = 0.23, broken down by vote_warnock_loeffler
# Kelly Loeffler     12.907154
# Raphael Warnock    85.553047
# Undecided           1.539799
# dtype: float64
# -
# lv_index = 0.23, broken down by vote_ossoff_perdue
# David Perdue    13.088316
# Jon Ossoff      85.497349
# Undecided        1.414335
# dtype: float64
# -
# lv_index = 0.11, broken down by loc_county
# Another county in Georgia    90.265063
# Gwinnett County, GA           9.734937
# dtype: float64
# -
# lv_index = 0.11, broken down by gender
# Female    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by race
# Black, non-Hispanic    28.632026
# White, not Hispanic    71.367974
# dtype: float64
# -
# lv_index = 0.11, broken down by education
# Graduated from high school    83.645195
# Some college, no degree       16.354805
# dtype: float64
# -
# lv_index = 0.11, broken down by income
# Between $15,000 and $49,999    39.544059
# Between $50,000 and $74,999    31.823915
# Under $15,000                  28.632026
# dtype: float64
# -
# lv_index = 0.11, broken down by age
# 18-34    76.810746
# 35-54    23.189254
# dtype: float64
# -
# lv_index = 0.11, broken down by vote2016
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by vote2020
# Did not vote    100.0
# dtype: float64
# -
# lv_index = 0.11, broken down by vote_warnock_loeffler
# Kelly Loeffler     31.823915
# Raphael Warnock    35.251895
# Undecided          32.924190
# dtype: float64
# -
# lv_index = 0.11, broken down by vote_ossoff_perdue
# David Perdue    31.823915
# Jon Ossoff      35.251895
# Undecided       32.924190
# dtype: float64
# -

# %% [markdown]
# ## Demographic by Enthusiasm

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- enthusiasm breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_['enthusiasm'].value_counts(normalize=True) * survey_.groupby('enthusiasm')['weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- enthusiasm breakdown for "Another county in Georgia"
# About the same       14.904883
# Less enthusiastic    14.671138
# More enthusiastic    70.423980
# dtype: float64
# -
# ---- enthusiasm breakdown for "Cobb County, GA"
# About the same       23.944060
# Less enthusiastic    20.520599
# More enthusiastic    55.535341
# dtype: float64
# -
# ---- enthusiasm breakdown for "DeKalb County, GA"
# About the same       31.455379
# Less enthusiastic     1.411728
# More enthusiastic    67.132892
# dtype: float64
# -
# ---- enthusiasm breakdown for "Fulton County, GA"
# About the same       14.646203
# Less enthusiastic     9.830627
# More enthusiastic    75.523171
# dtype: float64
# -
# ---- enthusiasm breakdown for "Gwinnett County, GA"
# About the same       12.258662
# Less enthusiastic     9.158847
# More enthusiastic    78.582491
# dtype: float64
# -
# ## gender ##
# ---- enthusiasm breakdown for "Female"
# About the same       18.175587
# Less enthusiastic    15.511048
# More enthusiastic    66.313365
# dtype: float64
# -
# ---- enthusiasm breakdown for "Male"
# About the same       14.731304
# Less enthusiastic    10.861158
# More enthusiastic    74.407538
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same        2.843893
# Less enthusiastic     2.211516
# More enthusiastic    94.944591
# dtype: float64
# -
# ---- enthusiasm breakdown for "Prefer not to say"
# About the same    100.0
# dtype: float64
# -
# ## race ##
# ---- enthusiasm breakdown for "White, not Hispanic"
# About the same       15.934307
# Less enthusiastic    14.518859
# More enthusiastic    69.546834
# dtype: float64
# -
# ---- enthusiasm breakdown for "Black, non-Hispanic"
# About the same       16.658498
# Less enthusiastic    10.254307
# More enthusiastic    73.087195
# dtype: float64
# -
# ---- enthusiasm breakdown for "Hispanic"
# About the same       22.447464
# Less enthusiastic    15.562688
# More enthusiastic    61.989849
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same        9.829747
# Less enthusiastic    13.495606
# More enthusiastic    76.674647
# dtype: float64
# -
# ## education ##
# ---- enthusiasm breakdown for "Completed graduate school"
# About the same       19.867581
# Less enthusiastic     7.563815
# More enthusiastic    72.568604
# dtype: float64
# -
# ---- enthusiasm breakdown for "Graduated from high school"
# About the same       18.436904
# Less enthusiastic    14.682327
# More enthusiastic    66.880769
# dtype: float64
# -
# ---- enthusiasm breakdown for "Graduated from college"
# About the same       13.491298
# Less enthusiastic    13.321296
# More enthusiastic    73.187406
# dtype: float64
# -
# ---- enthusiasm breakdown for "Some college, no degree"
# About the same       17.436464
# Less enthusiastic    15.527666
# More enthusiastic    67.035870
# dtype: float64
# -
# ---- enthusiasm breakdown for "Less than high school"
# About the same       12.063818
# Less enthusiastic     8.656148
# More enthusiastic    79.280035
# dtype: float64
# -
# ## income ##
# ---- enthusiasm breakdown for "Between $100,000 and $150,000"
# About the same       11.057397
# Less enthusiastic     6.762573
# More enthusiastic    82.180030
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $50,000 and $74,999"
# About the same       20.634291
# Less enthusiastic    14.321685
# More enthusiastic    65.044024
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $15,000 and $49,999"
# About the same       19.475864
# Less enthusiastic    11.360376
# More enthusiastic    69.163759
# dtype: float64
# -
# ---- enthusiasm breakdown for "Under $15,000"
# About the same       12.261337
# Less enthusiastic    16.675548
# More enthusiastic    71.063116
# dtype: float64
# -
# ---- enthusiasm breakdown for "Between $75,000 and $99,999"
# About the same       17.705129
# Less enthusiastic    20.193395
# More enthusiastic    62.101476
# dtype: float64
# -
# ---- enthusiasm breakdown for "Over $150,000"
# About the same        8.840745
# Less enthusiastic    12.230036
# More enthusiastic    78.929219
# dtype: float64
# -
# ## age ##
# ---- enthusiasm breakdown for "18-34"
# About the same       21.886183
# Less enthusiastic     8.108086
# More enthusiastic    70.005731
# dtype: float64
# -
# ---- enthusiasm breakdown for "35-54"
# About the same       19.157334
# Less enthusiastic    15.529139
# More enthusiastic    65.313526
# dtype: float64
# -
# ---- enthusiasm breakdown for "55-64"
# About the same        5.510565
# Less enthusiastic    20.281471
# More enthusiastic    74.207964
# dtype: float64
# -
# ---- enthusiasm breakdown for "65 or older"
# About the same       13.256324
# Less enthusiastic     9.993827
# More enthusiastic    76.749849
# dtype: float64
# -
# ## vote2016 ##
# ---- enthusiasm breakdown for "Hillary Clinton"
# About the same       13.846453
# Less enthusiastic     5.705751
# More enthusiastic    80.447796
# dtype: float64
# -
# ---- enthusiasm breakdown for "Did not vote"
# About the same       23.587111
# Less enthusiastic    12.422368
# More enthusiastic    63.990521
# dtype: float64
# -
# ---- enthusiasm breakdown for "Donald Trump"
# About the same       17.02533
# Less enthusiastic    17.79094
# More enthusiastic    65.18373
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same       13.674268
# Less enthusiastic    40.259226
# More enthusiastic    46.066506
# dtype: float64
# -
# ## vote2020 ##
# ---- enthusiasm breakdown for "Joe Biden"
# About the same       15.335622
# Less enthusiastic     7.281812
# More enthusiastic    77.382566
# dtype: float64
# -
# ---- enthusiasm breakdown for "Donald Trump"
# About the same       16.512933
# Less enthusiastic    19.206523
# More enthusiastic    64.280544
# dtype: float64
# -
# ---- enthusiasm breakdown for "Did not vote"
# About the same       41.823494
# Less enthusiastic     4.682744
# More enthusiastic    53.493762
# dtype: float64
# -
# ---- enthusiasm breakdown for "Other"
# About the same       25.575036
# Less enthusiastic    20.844133
# More enthusiastic    53.580831
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- enthusiasm breakdown for "Raphael Warnock"
# About the same       15.085791
# Less enthusiastic     9.074110
# More enthusiastic    75.840099
# dtype: float64
# -
# ---- enthusiasm breakdown for "Undecided"
# About the same       33.318082
# Less enthusiastic    25.614671
# More enthusiastic    41.067247
# dtype: float64
# -
# ---- enthusiasm breakdown for "Kelly Loeffler"
# About the same       16.626474
# Less enthusiastic    16.520004
# More enthusiastic    66.853523
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- enthusiasm breakdown for "Jon Ossoff"
# About the same       15.506325
# Less enthusiastic     9.106944
# More enthusiastic    75.386732
# dtype: float64
# -
# ---- enthusiasm breakdown for "David Perdue"
# About the same       16.889460
# Less enthusiastic    16.911253
# More enthusiastic    66.199287
# dtype: float64
# -
# ---- enthusiasm breakdown for "Undecided"
# About the same       22.284333
# Less enthusiastic    18.512789
# More enthusiastic    59.202878
# dtype: float64
# -
# <ipython-input-108-051615e720f2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])

# %% [markdown]
# ## Enthusiasm by Demographic

# %%
for enth in sorted(survey['enthusiasm'].unique())[::-1]:
    for var in demographics:
        print('enthusiasm = {}, broken down by {}'.format(enth, var))
        survey_ = survey[survey['enthusiasm'] == enth]
        survey_['weight'] = normalize_weights(survey_['weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# enthusiasm = More enthusiastic, broken down by loc_county
# <ipython-input-109-2d28f7f77c34>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['weight'] = normalize_weights(survey_['weight'])
# Another county in Georgia    66.931290
# Cobb County, GA               5.684157
# DeKalb County, GA             6.818343
# Fulton County, GA            10.732607
# Gwinnett County, GA           9.833602
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by gender
# Female    48.134357
# Male      51.056523
# Other      0.809119
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by race
# Black, non-Hispanic    33.866618
# Hispanic                8.721566
# Other                   5.992500
# White, not Hispanic    51.419316
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by education
# Completed graduate school      9.390656
# Graduated from college        19.044358
# Graduated from high school    28.612265
# Less than high school         15.886583
# Some college, no degree       27.066138
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by income
# Between $100,000 and $150,000    14.099337
# Between $15,000 and $49,999      34.654563
# Between $50,000 and $74,999      16.649479
# Between $75,000 and $99,999      10.240385
# Over $150,000                    10.452739
# Under $15,000                    13.903497
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by age
# 18-34          27.654260
# 35-54          33.338269
# 55-64          17.621859
# 65 or older    21.385612
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote2016
# Did not vote       11.584609
# Donald Trump       40.777347
# Hillary Clinton    45.180829
# Other               2.457215
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote2020
# Did not vote     1.298991
# Donald Trump    44.280429
# Joe Biden       53.522167
# Other            0.898413
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote_warnock_loeffler
# Kelly Loeffler     44.586165
# Raphael Warnock    53.266050
# Undecided           2.147786
# dtype: float64
# -
# enthusiasm = More enthusiastic, broken down by vote_ossoff_perdue
# David Perdue    43.473901
# Jon Ossoff      52.377959
# Undecided        4.148140
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by loc_county
# Another county in Georgia    74.443365
# Cobb County, GA              11.213476
# DeKalb County, GA             0.765505
# Fulton County, GA             7.458643
# Gwinnett County, GA           6.119011
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by gender
# Female    60.110288
# Male      39.789091
# Other      0.100620
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by race
# Black, non-Hispanic    25.368243
# Hispanic               11.689934
# Other                   5.631217
# White, not Hispanic    57.310606
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by education
# Completed graduate school      5.225666
# Graduated from college        18.506746
# Graduated from high school    33.535086
# Less than high school          9.260723
# Some college, no degree       33.471779
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by income
# Between $100,000 and $150,000     6.194381
# Between $15,000 and $49,999      30.389820
# Between $50,000 and $74,999      19.572258
# Between $75,000 and $99,999      17.777769
# Over $150,000                     8.647163
# Under $15,000                    17.418610
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by age
# 18-34          17.100167
# 35-54          42.319533
# 55-64          25.713087
# 65 or older    14.867213
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote2016
# Did not vote       12.006701
# Donald Trump       59.419943
# Hillary Clinton    17.108282
# Other              11.465074
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote2020
# Did not vote     0.607095
# Donald Trump    70.637383
# Joe Biden       26.889554
# Other            1.865967
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote_warnock_loeffler
# Kelly Loeffler     58.821965
# Raphael Warnock    34.025868
# Undecided           7.152168
# dtype: float64
# -
# enthusiasm = Less enthusiastic, broken down by vote_ossoff_perdue
# David Perdue    59.293167
# Jon Ossoff      33.781574
# Undecided        6.925259
# dtype: float64
# -
# enthusiasm = About the same, broken down by loc_county
# Another county in Georgia    60.468459
# Cobb County, GA              10.461312
# DeKalb County, GA            13.637354
# Fulton County, GA             8.884680
# Gwinnett County, GA           6.548195
# dtype: float64
# -
# enthusiasm = About the same, broken down by gender
# Female               56.316320
# Male                 43.148650
# Other                 0.103454
# Prefer not to say     0.431576
# dtype: float64
# -
# enthusiasm = About the same, broken down by race
# Black, non-Hispanic    32.950203
# Hispanic               13.481334
# Other                   3.279369
# White, not Hispanic    50.289093
# dtype: float64
# -
# enthusiasm = About the same, broken down by education
# Completed graduate school     10.974478
# Graduated from college        14.985645
# Graduated from high school    33.669037
# Less than high school         10.319131
# Some college, no degree       30.051709
# dtype: float64
# -
# enthusiasm = About the same, broken down by income
# Between $100,000 and $150,000     8.097986
# Between $15,000 and $49,999      41.655302
# Between $50,000 and $74,999      22.546260
# Between $75,000 and $99,999      12.462500
# Over $150,000                     4.997731
# Under $15,000                    10.240221
# dtype: float64
# -
# enthusiasm = About the same, broken down by age
# 18-34          36.905423
# 35-54          41.741370
# 55-64           5.585847
# 65 or older    15.767359
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote2016
# Did not vote       18.227713
# Donald Trump       45.463934
# Hillary Clinton    33.194818
# Other               3.113535
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote2020
# Did not vote     4.335258
# Donald Trump    48.556595
# Joe Biden       45.277627
# Other            1.830520
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote_warnock_loeffler
# Kelly Loeffler     47.333397
# Raphael Warnock    45.228417
# Undecided           7.438186
# dtype: float64
# -
# enthusiasm = About the same, broken down by vote_ossoff_perdue
# David Perdue    47.345943
# Jon Ossoff      45.989029
# Undecided        6.665028
# dtype: float64
# -

# %% [markdown]
# ## Demographic by Vote Method

# %%
for var in demographics:
    print('## {} ##'.format(var))
    options = survey[var].unique()
    for option in options:
        print('---- vote method breakdown for "{}"'.format(option))
        survey_ = survey[survey[var] == option]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print(survey_['vote_method'].value_counts(normalize=True) * survey_.groupby('vote_method')['lv_weight'].mean() * 100)
        print('-')
# Out:
# ## loc_county ##
# ---- vote method breakdown for "Another county in Georgia"
# Absentee by mail               32.861080
# Early vote in person           48.060987
# I will vote on election day    19.077933
# dtype: float64
# -
# ---- vote method breakdown for "Cobb County, GA"
# Absentee by mail               48.140608
# Early vote in person           35.986649
# I will vote on election day    15.872743
# dtype: float64
# -
# ---- vote method breakdown for "DeKalb County, GA"
# Absentee by mail               54.774018
# Early vote in person           28.778601
# I will vote on election day    16.447381
# dtype: float64
# -
# ---- vote method breakdown for "Fulton County, GA"
# Absentee by mail               31.829426
# Early vote in person           48.055665
# I will vote on election day    20.114909
# dtype: float64
# -
# ---- vote method breakdown for "Gwinnett County, GA"
# Absentee by mail               37.415483
# Early vote in person           42.350396
# I will vote on election day    20.234121
# dtype: float64
# -
# ## gender ##
# ---- vote method breakdown for "Female"
# Absentee by mail               34.590760
# Early vote in person           46.932134
# I will vote on election day    18.477106
# dtype: float64
# -
# ---- vote method breakdown for "Male"
# Absentee by mail               36.215856
# Early vote in person           44.179624
# I will vote on election day    19.604519
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail        30.156101
# Early vote in person    69.843899
# dtype: float64
# -
# ---- vote method breakdown for "Prefer not to say"
# Early vote in person    100.0
# dtype: float64
# -
# ## race ##
# ---- vote method breakdown for "White, not Hispanic"
# Absentee by mail               33.263753
# Early vote in person           41.765257
# I will vote on election day    24.970989
# dtype: float64
# -
# ---- vote method breakdown for "Black, non-Hispanic"
# <ipython-input-110-a76a51f2b65b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# Absentee by mail               40.765431
# Early vote in person           49.639813
# I will vote on election day     9.594756
# dtype: float64
# -
# ---- vote method breakdown for "Hispanic"
# Absentee by mail               30.717393
# Early vote in person           50.805589
# I will vote on election day    18.477018
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               30.860907
# Early vote in person           52.614419
# I will vote on election day    16.524674
# dtype: float64
# -
# ## education ##
# ---- vote method breakdown for "Completed graduate school"
# Absentee by mail               40.803575
# Early vote in person           47.556312
# I will vote on election day    11.640113
# dtype: float64
# -
# ---- vote method breakdown for "Graduated from high school"
# Absentee by mail               42.645985
# Early vote in person           38.393593
# I will vote on election day    18.960422
# dtype: float64
# -
# ---- vote method breakdown for "Graduated from college"
# Absentee by mail               27.658425
# Early vote in person           51.982513
# I will vote on election day    20.359062
# dtype: float64
# -
# ---- vote method breakdown for "Some college, no degree"
# Absentee by mail               26.291208
# Early vote in person           51.076579
# I will vote on election day    22.632213
# dtype: float64
# -
# ---- vote method breakdown for "Less than high school"
# Absentee by mail               42.857570
# Early vote in person           42.344647
# I will vote on election day    14.797783
# dtype: float64
# -
# ## income ##
# ---- vote method breakdown for "Between $100,000 and $150,000"
# Absentee by mail               28.294370
# Early vote in person           51.761882
# I will vote on election day    19.943749
# dtype: float64
# -
# ---- vote method breakdown for "Between $50,000 and $74,999"
# Absentee by mail               26.589932
# Early vote in person           59.303597
# I will vote on election day    14.106471
# dtype: float64
# -
# ---- vote method breakdown for "Between $15,000 and $49,999"
# Absentee by mail               44.143132
# Early vote in person           39.782880
# I will vote on election day    16.073988
# dtype: float64
# -
# ---- vote method breakdown for "Under $15,000"
# Absentee by mail               53.425136
# Early vote in person           30.865683
# I will vote on election day    15.709181
# dtype: float64
# -
# ---- vote method breakdown for "Between $75,000 and $99,999"
# Absentee by mail               18.341436
# Early vote in person           58.211346
# I will vote on election day    23.447218
# dtype: float64
# -
# ---- vote method breakdown for "Over $150,000"
# Absentee by mail               24.712380
# Early vote in person           40.203754
# I will vote on election day    35.083866
# dtype: float64
# -
# ## age ##
# ---- vote method breakdown for "18-34"
# Absentee by mail               36.644483
# Early vote in person           51.701000
# I will vote on election day    11.654518
# dtype: float64
# -
# ---- vote method breakdown for "35-54"
# Absentee by mail               24.143438
# Early vote in person           47.140894
# I will vote on election day    28.715667
# dtype: float64
# -
# ---- vote method breakdown for "55-64"
# Absentee by mail               33.540951
# Early vote in person           49.923496
# I will vote on election day    16.535553
# dtype: float64
# -
# ---- vote method breakdown for "65 or older"
# Absentee by mail               54.394558
# Early vote in person           33.217046
# I will vote on election day    12.388396
# dtype: float64
# -
# ## vote2016 ##
# ---- vote method breakdown for "Hillary Clinton"
# Absentee by mail               51.752685
# Early vote in person           43.621345
# I will vote on election day     4.625971
# dtype: float64
# -
# ---- vote method breakdown for "Did not vote"
# Absentee by mail               24.595750
# Early vote in person           57.380233
# I will vote on election day    18.024017
# dtype: float64
# -
# ---- vote method breakdown for "Donald Trump"
# Absentee by mail               23.611492
# Early vote in person           44.980718
# I will vote on election day    31.407789
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               43.298790
# Early vote in person           45.357464
# I will vote on election day    11.343746
# dtype: float64
# -
# ## vote2020 ##
# ---- vote method breakdown for "Joe Biden"
# Absentee by mail               49.034811
# Early vote in person           43.806993
# I will vote on election day     7.158197
# dtype: float64
# -
# ---- vote method breakdown for "Donald Trump"
# Absentee by mail               23.782947
# Early vote in person           47.083155
# I will vote on election day    29.133898
# dtype: float64
# -
# ---- vote method breakdown for "Did not vote"
# Absentee by mail               39.906684
# Early vote in person           45.709494
# I will vote on election day    14.383822
# dtype: float64
# -
# ---- vote method breakdown for "Other"
# Absentee by mail               10.445607
# Early vote in person           61.631735
# I will vote on election day    27.922658
# dtype: float64
# -
# ## vote_warnock_loeffler ##
# ---- vote method breakdown for "Raphael Warnock"
# Absentee by mail               48.233111
# Early vote in person           44.865200
# I will vote on election day     6.901690
# dtype: float64
# -
# ---- vote method breakdown for "Undecided"
# Absentee by mail               32.344517
# Early vote in person           41.248891
# I will vote on election day    26.406593
# dtype: float64
# -
# ---- vote method breakdown for "Kelly Loeffler"
# Absentee by mail               23.726724
# Early vote in person           46.838281
# I will vote on election day    29.434996
# dtype: float64
# -
# ## vote_ossoff_perdue ##
# ---- vote method breakdown for "Jon Ossoff"
# Absentee by mail               47.533609
# Early vote in person           45.119427
# I will vote on election day     7.346965
# dtype: float64
# -
# ---- vote method breakdown for "David Perdue"
# Absentee by mail               24.696646
# Early vote in person           45.452318
# I will vote on election day    29.851037
# dtype: float64
# -
# ---- vote method breakdown for "Undecided"
# Absentee by mail               29.669413
# Early vote in person           54.239724
# I will vote on election day    16.090863
# dtype: float64
# -

# %% [markdown]
# ## Vote Method by Demographic

# %%
for method in sorted(survey['vote_method'].unique())[::-1]:
    for var in demographics:
        print('vote method = "{}", broken down by {}'.format(method, var))
        survey_ = survey[survey['vote_method'] == method]
        survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
        print(survey_[var].value_counts(normalize=True) * survey_.groupby(var)['weight'].mean() * 100)
        print('-')
# Out:
# vote method = "I will vote on election day", broken down by loc_county
# <ipython-input-111-8d3ff2d10575>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_['lv_weight'] = normalize_weights(survey_['lv_weight'])
# Another county in Georgia    90.736556
# Cobb County, GA               7.488519
# DeKalb County, GA             5.723386
# Fulton County, GA            12.449200
# Gwinnett County, GA          11.769604
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by gender
# Female    62.718876
# Male      65.448388
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by race
# Black, non-Hispanic    20.831099
# Hispanic               11.197176
# Other                   5.948250
# White, not Hispanic    90.190740
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by education
# Completed graduate school      7.078958
# Graduated from college        24.046423
# Graduated from high school    38.270115
# Less than high school         15.832429
# Some college, no degree       42.939339
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by income
# Between $100,000 and $150,000    16.396150
# Between $15,000 and $49,999      37.054632
# Between $50,000 and $74,999      16.669331
# Between $75,000 and $99,999      19.894797
# Over $150,000                    22.917079
# Under $15,000                    15.235275
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by age
# 18-34          18.895797
# 35-54          70.672114
# 55-64          20.511917
# 65 or older    18.087436
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote2016
# Did not vote       12.784150
# Donald Trump       99.675453
# Hillary Clinton    12.123380
# Other               3.584281
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote2020
# Did not vote      1.188656
# Donald Trump    102.627138
# Joe Biden        22.154233
# Other             2.197238
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote_warnock_loeffler
# Kelly Loeffler     99.823452
# Raphael Warnock    21.621515
# Undecided           6.722297
# dtype: float64
# -
# vote method = "I will vote on election day", broken down by vote_ossoff_perdue
# David Perdue    99.633039
# Jon Ossoff      22.601111
# Undecided        5.933115
# dtype: float64
# -
# vote method = "Early vote in person", broken down by loc_county
# Another county in Georgia    71.794323
# Cobb County, GA               5.322785
# DeKalb County, GA             5.373049
# Fulton County, GA            11.117626
# Gwinnett County, GA           8.888477
# dtype: float64
# -
# vote method = "Early vote in person", broken down by gender
# Female               52.702938
# Male                 48.625269
# Other                 1.007403
# Prefer not to say     0.160651
# dtype: float64
# -
# vote method = "Early vote in person", broken down by race
# Black, non-Hispanic    35.057513
# Hispanic               11.708984
# Other                   6.358886
# White, not Hispanic    49.370877
# dtype: float64
# -
# vote method = "Early vote in person", broken down by education
# Completed graduate school      9.356747
# Graduated from college        21.948896
# Graduated from high school    25.618465
# Less than high school         13.352877
# Some college, no degree       32.219275
# dtype: float64
# -
# vote method = "Early vote in person", broken down by income
# Between $100,000 and $150,000    13.590906
# Between $15,000 and $49,999      31.746114
# Between $50,000 and $74,999      23.683894
# Between $75,000 and $99,999      15.461423
# Over $150,000                     8.907629
# Under $15,000                     9.106295
# dtype: float64
# -
# vote method = "Early vote in person", broken down by age
# 18-34          30.741566
# 35-54          38.200356
# 55-64          18.865566
# 65 or older    14.688773
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote2016
# Did not vote       15.415040
# Donald Trump       44.407598
# Hillary Clinton    38.940751
# Other               3.732871
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote2020
# Did not vote     1.980517
# Donald Trump    51.209062
# Joe Biden       47.664031
# Other            1.642651
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote_warnock_loeffler
# Kelly Loeffler     49.675985
# Raphael Warnock    49.328525
# Undecided           3.491751
# dtype: float64
# -
# vote method = "Early vote in person", broken down by vote_ossoff_perdue
# David Perdue    47.541362
# Jon Ossoff      48.954614
# Undecided        6.000284
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by loc_county
# Another county in Georgia    54.024817
# Cobb County, GA               9.076425
# DeKalb County, GA             9.458055
# Fulton County, GA             8.035183
# Gwinnett County, GA           7.762258
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by gender
# Female    45.602631
# Male      42.390423
# Other      0.363684
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by race
# Black, non-Hispanic    33.783322
# Hispanic                7.579946
# Other                   4.450257
# White, not Hispanic    42.543213
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by education
# Completed graduate school      9.485088
# Graduated from college        12.642551
# Graduated from high school    32.169242
# Less than high school         14.319317
# Some college, no degree       19.740541
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by income
# Between $100,000 and $150,000     9.085773
# Between $15,000 and $49,999      38.338318
# Between $50,000 and $74,999      12.479495
# Between $75,000 and $99,999       4.891310
# Over $150,000                     5.386229
# Under $15,000                    18.175614
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by age
# 18-34          27.539574
# 35-54          22.361169
# 55-64          13.217809
# 65 or older    25.238185
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote2016
# Did not vote        9.908062
# Donald Trump       25.747973
# Hillary Clinton    48.874347
# Other               3.826356
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote2020
# Did not vote     1.588995
# Donald Trump    28.216033
# Joe Biden       58.184095
# Other            0.367615
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote_warnock_loeffler
# Kelly Loeffler     27.065874
# Raphael Warnock    58.390594
# Undecided           2.900270
# dtype: float64
# -
# vote method = "Absentee by mail", broken down by vote_ossoff_perdue
# David Perdue    27.664100
# Jon Ossoff      57.209471
# Undecided        3.483167
# dtype: float64
# -
